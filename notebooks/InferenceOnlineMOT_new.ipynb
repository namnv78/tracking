# %% [markdown]
# # Import libraries

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !wget https://motchallenge.net/data/MOT17.zip
# !unzip MOT17.zip 
# %rm MOT17.zip

# %%
# %cd /content/
# !wget https://motchallenge.net/data/MOT20.zip
# !unzip MOT20.zip 
# %rm MOT20.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: MOT20/train/MOT20-05/img1/000252.jpg
#   inflating: MOT20/train/MOT20-05/img1/002793.jpg
#   inflating: MOT20/train/MOT20-05/img1/001323.jpg
#   inflating: MOT20/train/MOT20-05/img1/002478.jpg
#   inflating: MOT20/train/MOT20-05/img1/002976.jpg
#   inflating: MOT20/train/MOT20-05/img1/001534.jpg
#   inflating: MOT20/train/MOT20-05/img1/001678.jpg
#   inflating: MOT20/train/MOT20-05/img1/000756.jpg
#   inflating: MOT20/train/MOT20-05/img1/000644.jpg
#   inflating: MOT20/train/MOT20-05/img1/000606.jpg
#   inflating: MOT20/train/MOT20-05/img1/001533.jpg
#   inflating: MOT20/train/MOT20-05/img1/002020.jpg
#   inflating: MOT20/train/MOT20-05/img1/001247.jpg
#   inflating: MOT20/train/MOT20-05/img1/001419.jpg
#   inflating: MOT20/train/MOT20-05/img1/001644.jpg
#   inflating: MOT20/train/MOT20-05/img1/002488.jpg
#   inflating: MOT20/train/MOT20-05/img1/003192.jpg
#   inflating: MOT20/train/MOT20-05/img1/000783.jpg
#   inflating: MOT20/train/MOT20-05/img1/000499.jpg
#   inflating: MOT20/train/MOT20-05/img1/001774.jpg
#   inflating: MOT20/train/MOT20-05/img1/000143.jpg
#   inflating: MOT20/train/MOT20-05/img1/001624.jpg
#   inflating: MOT20/train/MOT20-05/img1/001078.jpg
#   inflating: MOT20/train/MOT20-05/img1/002176.jpg
#   inflating: MOT20/train/MOT20-05/img1/001613.jpg
#   inflating: MOT20/train/MOT20-05/img1/001921.jpg
#   inflating: MOT20/train/MOT20-05/img1/003295.jpg
#   inflating: MOT20/train/MOT20-05/img1/001696.jpg
#   inflating: MOT20/train/MOT20-05/img1/000411.jpg
#   inflating: MOT20/train/MOT20-05/img1/001530.jpg
#   inflating: MOT20/train/MOT20-05/img1/000829.jpg
#   inflating: MOT20/train/MOT20-05/img1/002561.jpg
#   inflating: MOT20/train/MOT20-05/img1/002090.jpg
#   inflating: MOT20/train/MOT20-05/img1/002279.jpg
#   inflating: MOT20/train/MOT20-05/img1/002834.jpg
#   inflating: MOT20/train/MOT20-05/img1/003038.jpg
#   inflating: MOT20/train/MOT20-05/img1/001955.jpg
#   inflating: MOT20/train/MOT20-05/img1/001969.jpg
#   inflating: MOT20/train/MOT20-05/img1/002747.jpg
#   inflating: MOT20/train/MOT20-05/img1/002233.jpg
#   inflating: MOT20/train/MOT20-05/img1/002522.jpg
#   inflating: MOT20/train/MOT20-05/img1/002674.jpg
#   inflating: MOT20/train/MOT20-05/img1/001201.jpg
#   inflating: MOT20/train/MOT20-05/img1/002737.jpg
#   inflating: MOT20/train/MOT20-05/img1/002023.jpg
#   inflating: MOT20/train/MOT20-05/img1/001996.jpg
#   inflating: MOT20/train/MOT20-05/img1/002473.jpg
#   inflating: MOT20/train/MOT20-05/img1/001944.jpg
#   inflating: MOT20/train/MOT20-05/img1/000529.jpg
#   inflating: MOT20/train/MOT20-05/img1/001870.jpg
#   inflating: MOT20/train/MOT20-05/img1/002213.jpg
#   inflating: MOT20/train/MOT20-05/img1/002689.jpg
#   inflating: MOT20/train/MOT20-05/img1/000592.jpg
#   inflating: MOT20/train/MOT20-05/img1/002200.jpg
#   inflating: MOT20/train/MOT20-05/img1/001549.jpg
#   inflating: MOT20/train/MOT20-05/img1/001949.jpg
#   inflating: MOT20/train/MOT20-05/img1/000730.jpg
#   inflating: MOT20/train/MOT20-05/img1/001159.jpg
#   inflating: MOT20/train/MOT20-05/img1/000111.jpg
#   inflating: MOT20/train/MOT20-05/img1/002493.jpg
#   inflating: MOT20/train/MOT20-05/img1/001535.jpg
#   inflating: MOT20/train/MOT20-05/img1/000969.jpg
#   inflating: MOT20/train/MOT20-05/img1/000270.jpg
#   inflating: MOT20/train/MOT20-05/img1/000805.jpg
#   inflating: MOT20/train/MOT20-05/img1/002582.jpg
#   inflating: MOT20/train/MOT20-05/img1/001752.jpg
#   inflating: MOT20/train/MOT20-05/img1/002126.jpg
#   inflating: MOT20/train/MOT20-05/img1/002418.jpg
#   inflating: MOT20/train/MOT20-05/img1/001124.jpg
#   inflating: MOT20/train/MOT20-05/img1/001748.jpg
#   inflating: MOT20/train/MOT20-05/img1/001332.jpg
#   inflating: MOT20/train/MOT20-05/img1/001114.jpg
#   inflating: MOT20/train/MOT20-05/img1/002306.jpg
#   inflating: MOT20/train/MOT20-05/img1/000101.jpg
#   inflating: MOT20/train/MOT20-05/img1/001704.jpg
#   inflating: MOT20/train/MOT20-05/img1/002085.jpg
#   inflating: MOT20/train/MOT20-05/img1/002157.jpg
#   inflating: MOT20/train/MOT20-05/img1/000958.jpg
#   inflating: MOT20/train/MOT20-05/img1/001227.jpg
#   inflating: MOT20/train/MOT20-05/img1/000207.jpg
#   inflating: MOT20/train/MOT20-05/img1/001053.jpg
#   inflating: MOT20/train/MOT20-05/img1/002537.jpg
#   inflating: MOT20/train/MOT20-05/img1/000876.jpg
#   inflating: MOT20/train/MOT20-05/img1/002879.jpg
#   inflating: MOT20/train/MOT20-05/img1/002596.jpg
#   inflating: MOT20/train/MOT20-05/img1/002515.jpg
#   inflating: MOT20/train/MOT20-05/img1/000469.jpg
#   inflating: MOT20/train/MOT20-05/img1/002192.jpg
#   inflating: MOT20/train/MOT20-05/img1/000498.jpg
#   inflating: MOT20/train/MOT20-05/img1/000599.jpg
#   inflating: MOT20/train/MOT20-05/img1/002036.jpg
#   inflating: MOT20/train/MOT20-05/img1/001025.jpg
#   inflating: MOT20/train/MOT20-05/img1/001619.jpg
#   inflating: MOT20/train/MOT20-05/img1/003246.jpg
#   inflating: MOT20/train/MOT20-05/img1/000226.jpg
#   inflating: MOT20/train/MOT20-05/img1/002046.jpg
#   inflating: MOT20/train/MOT20-05/img1/002098.jpg
#   inflating: MOT20/train/MOT20-05/img1/000898.jpg
#   inflating: MOT20/train/MOT20-05/img1/003026.jpg
#   inflating: MOT20/train/MOT20-05/img1/003315.jpg
#   inflating: MOT20/train/MOT20-05/img1/003160.jpg
#   inflating: MOT20/train/MOT20-05/img1/002261.jpg
#   inflating: MOT20/train/MOT20-05/img1/001692.jpg
#   inflating: MOT20/train/MOT20-05/img1/000608.jpg
#   inflating: MOT20/train/MOT20-05/img1/003126.jpg
#   inflating: MOT20/train/MOT20-05/img1/002351.jpg
#   inflating: MOT20/train/MOT20-05/img1/001643.jpg
#   inflating: MOT20/train/MOT20-05/img1/002640.jpg
#   inflating: MOT20/train/MOT20-05/img1/002463.jpg
#   inflating: MOT20/train/MOT20-05/img1/000991.jpg
#   inflating: MOT20/train/MOT20-05/img1/000062.jpg
#   inflating: MOT20/train/MOT20-05/img1/003147.jpg
#   inflating: MOT20/train/MOT20-05/img1/000611.jpg
#   inflating: MOT20/train/MOT20-05/img1/000232.jpg
#   inflating: MOT20/train/MOT20-05/img1/000041.jpg
#   inflating: MOT20/train/MOT20-05/img1/001686.jpg
#   inflating: MOT20/train/MOT20-05/img1/000539.jpg
#   inflating: MOT20/train/MOT20-05/img1/002511.jpg
#   inflating: MOT20/train/MOT20-05/img1/001008.jpg
#   inflating: MOT20/train/MOT20-05/img1/001574.jpg
#   inflating: MOT20/train/MOT20-05/img1/000880.jpg
#   inflating: MOT20/train/MOT20-05/img1/002593.jpg
#   inflating: MOT20/train/MOT20-05/img1/002829.jpg
#   inflating: MOT20/train/MOT20-05/img1/001031.jpg
#   inflating: MOT20/train/MOT20-05/img1/000212.jpg
#   inflating: MOT20/train/MOT20-05/img1/000022.jpg
#   inflating: MOT20/train/MOT20-05/img1/002815.jpg
#   inflating: MOT20/train/MOT20-05/img1/000759.jpg
#   inflating: MOT20/train/MOT20-05/img1/001504.jpg
#   inflating: MOT20/train/MOT20-05/img1/000287.jpg
#   inflating: MOT20/train/MOT20-05/img1/001261.jpg
#   inflating: MOT20/train/MOT20-05/img1/002112.jpg
#   inflating: MOT20/train/MOT20-05/img1/001848.jpg
#   inflating: MOT20/train/MOT20-05/img1/001046.jpg
#   inflating: MOT20/train/MOT20-05/img1/000753.jpg
#   inflating: MOT20/train/MOT20-05/img1/001029.jpg
#   inflating: MOT20/train/MOT20-05/img1/001495.jpg
#   inflating: MOT20/train/MOT20-05/img1/003156.jpg
#   inflating: MOT20/train/MOT20-05/img1/003135.jpg
#   inflating: MOT20/train/MOT20-05/img1/002788.jpg
#   inflating: MOT20/train/MOT20-05/img1/000097.jpg
#   inflating: MOT20/train/MOT20-05/img1/001224.jpg
#   inflating: MOT20/train/MOT20-05/img1/000628.jpg
#   inflating: MOT20/train/MOT20-05/img1/001655.jpg
#   inflating: MOT20/train/MOT20-05/img1/001605.jpg
#   inflating: MOT20/train/MOT20-05/img1/001374.jpg
#   inflating: MOT20/train/MOT20-05/img1/002715.jpg
#   inflating: MOT20/train/MOT20-05/img1/002499.jpg
#   inflating: MOT20/train/MOT20-05/img1/000368.jpg
#   inflating: MOT20/train/MOT20-05/img1/002327.jpg
#   inflating: MOT20/train/MOT20-05/img1/000090.jpg
#   inflating: MOT20/train/MOT20-05/img1/000321.jpg
#   inflating: MOT20/train/MOT20-05/img1/003112.jpg
#   inflating: MOT20/train/MOT20-05/img1/002491.jpg
#   inflating: MOT20/train/MOT20-05/img1/002411.jpg
#   inflating: MOT20/train/MOT20-05/img1/002822.jpg
#   inflating: MOT20/train/MOT20-05/img1/002521.jpg
#   inflating: MOT20/train/MOT20-05/img1/001778.jpg
#   inflating: MOT20/train/MOT20-05/img1/000302.jpg
#   inflating: MOT20/train/MOT20-05/img1/001628.jpg
#   inflating: MOT20/train/MOT20-05/img1/002162.jpg
#   inflating: MOT20/train/MOT20-05/img1/001956.jpg
#   inflating: MOT20/train/MOT20-05/img1/000510.jpg
#   inflating: MOT20/train/MOT20-05/img1/001544.jpg
#   inflating: MOT20/train/MOT20-05/img1/000561.jpg
#   inflating: MOT20/train/MOT20-05/img1/000371.jpg
#   inflating: MOT20/train/MOT20-05/img1/001562.jpg
#   inflating: MOT20/train/MOT20-05/img1/003086.jpg
#   inflating: MOT20/train/MOT20-05/img1/000629.jpg
#   inflating: MOT20/train/MOT20-05/img1/002842.jpg
#   inflating: MOT20/train/MOT20-05/img1/000884.jpg
#   inflating: MOT20/train/MOT20-05/img1/000901.jpg
#   inflating: MOT20/train/MOT20-05/img1/002038.jpg
#   inflating: MOT20/train/MOT20-05/img1/002594.jpg
#   inflating: MOT20/train/MOT20-05/img1/000051.jpg
#   inflating: MOT20/train/MOT20-05/img1/003066.jpg
#   inflating: MOT20/train/MOT20-05/img1/000393.jpg
#   inflating: MOT20/train/MOT20-05/img1/000296.jpg
#   inflating: MOT20/train/MOT20-05/img1/002798.jpg
#   inflating: MOT20/train/MOT20-05/img1/001513.jpg
#   inflating: MOT20/train/MOT20-05/img1/001739.jpg
#   inflating: MOT20/train/MOT20-05/img1/003164.jpg
#   inflating: MOT20/train/MOT20-05/img1/001888.jpg
#   inflating: MOT20/train/MOT20-05/img1/002517.jpg
#   inflating: MOT20/train/MOT20-05/img1/002893.jpg
#   inflating: MOT20/train/MOT20-05/img1/000288.jpg
#   inflating: MOT20/train/MOT20-05/img1/001087.jpg
#   inflating: MOT20/train/MOT20-05/img1/001966.jpg
#   inflating: MOT20/train/MOT20-05/img1/001349.jpg
#   inflating: MOT20/train/MOT20-05/img1/000995.jpg
#   inflating: MOT20/train/MOT20-05/img1/001218.jpg
#   inflating: MOT20/train/MOT20-05/img1/000155.jpg
#   inflating: MOT20/train/MOT20-05/img1/000158.jpg
#   inflating: MOT20/train/MOT20-05/img1/002904.jpg
#   inflating: MOT20/train/MOT20-05/img1/002108.jpg
#   inflating: MOT20/train/MOT20-05/img1/000442.jpg
#   inflating: MOT20/train/MOT20-05/img1/002974.jpg
#   inflating: MOT20/train/MOT20-05/img1/000970.jpg
#   inflating: MOT20/train/MOT20-05/img1/002802.jpg
#   inflating: MOT20/train/MOT20-05/img1/001405.jpg
#   inflating: MOT20/train/MOT20-05/img1/000634.jpg
#   inflating: MOT20/train/MOT20-05/img1/000145.jpg
#   inflating: MOT20/train/MOT20-05/img1/001225.jpg
#   inflating: MOT20/train/MOT20-05/img1/002276.jpg
#   inflating: MOT20/train/MOT20-05/img1/002018.jpg
#   inflating: MOT20/train/MOT20-05/img1/001801.jpg
#   inflating: MOT20/train/MOT20-05/img1/000631.jpg
#   inflating: MOT20/train/MOT20-05/img1/001727.jpg
#   inflating: MOT20/train/MOT20-05/img1/000892.jpg
#   inflating: MOT20/train/MOT20-05/img1/002849.jpg
#   inflating: MOT20/train/MOT20-05/img1/002927.jpg
#   inflating: MOT20/train/MOT20-05/img1/000506.jpg
#   inflating: MOT20/train/MOT20-05/img1/000579.jpg
#   inflating: MOT20/train/MOT20-05/img1/000620.jpg
#   inflating: MOT20/train/MOT20-05/img1/001766.jpg
#   inflating: MOT20/train/MOT20-05/img1/001854.jpg
#   inflating: MOT20/train/MOT20-05/img1/002558.jpg
#   inflating: MOT20/train/MOT20-05/img1/000733.jpg
#   inflating: MOT20/train/MOT20-05/img1/001965.jpg
#   inflating: MOT20/train/MOT20-05/img1/002274.jpg
#   inflating: MOT20/train/MOT20-05/img1/001291.jpg
#   inflating: MOT20/train/MOT20-05/img1/001934.jpg
#   inflating: MOT20/train/MOT20-05/img1/003245.jpg
#   inflating: MOT20/train/MOT20-05/img1/002025.jpg
#   inflating: MOT20/train/MOT20-05/img1/002682.jpg
#   inflating: MOT20/train/MOT20-05/img1/003181.jpg
#   inflating: MOT20/train/MOT20-05/img1/002987.jpg
#   inflating: MOT20/train/MOT20-05/img1/000927.jpg
#   inflating: MOT20/train/MOT20-05/img1/000840.jpg
#   inflating: MOT20/train/MOT20-05/img1/001320.jpg
#   inflating: MOT20/train/MOT20-05/img1/003281.jpg
#   inflating: MOT20/train/MOT20-05/img1/001941.jpg
#   inflating: MOT20/train/MOT20-05/img1/000832.jpg
#   inflating: MOT20/train/MOT20-05/img1/001281.jpg
#   inflating: MOT20/train/MOT20-05/img1/002050.jpg
#   inflating: MOT20/train/MOT20-05/img1/002549.jpg
#   inflating: MOT20/train/MOT20-05/img1/000066.jpg
#   inflating: MOT20/train/MOT20-05/img1/003024.jpg
#   inflating: MOT20/train/MOT20-05/img1/002973.jpg
#   inflating: MOT20/train/MOT20-05/img1/003113.jpg
#   inflating: MOT20/train/MOT20-05/img1/001241.jpg
#   inflating: MOT20/train/MOT20-05/img1/001617.jpg
#   inflating: MOT20/train/MOT20-05/img1/000624.jpg
#   inflating: MOT20/train/MOT20-05/img1/001916.jpg
#   inflating: MOT20/train/MOT20-05/img1/001319.jpg
#   inflating: MOT20/train/MOT20-05/img1/001878.jpg
#   inflating: MOT20/train/MOT20-05/img1/002393.jpg
#   inflating: MOT20/train/MOT20-05/img1/001904.jpg
#   inflating: MOT20/train/MOT20-05/img1/000754.jpg
#   inflating: MOT20/train/MOT20-05/img1/002331.jpg
#   inflating: MOT20/train/MOT20-05/img1/000192.jpg
#   inflating: MOT20/train/MOT20-05/img1/003119.jpg
#   inflating: MOT20/train/MOT20-05/img1/003081.jpg
#   inflating: MOT20/train/MOT20-05/img1/002428.jpg
#   inflating: MOT20/train/MOT20-05/img1/001695.jpg
#   inflating: MOT20/train/MOT20-05/img1/000120.jpg
#   inflating: MOT20/train/MOT20-05/img1/003266.jpg
#   inflating: MOT20/train/MOT20-05/img1/002022.jpg
#   inflating: MOT20/train/MOT20-05/img1/002734.jpg
#   inflating: MOT20/train/MOT20-05/img1/000567.jpg
#   inflating: MOT20/train/MOT20-05/img1/002030.jpg
#   inflating: MOT20/train/MOT20-05/img1/001449.jpg
#   inflating: MOT20/train/MOT20-05/img1/002654.jpg
#   inflating: MOT20/train/MOT20-05/img1/001152.jpg
#   inflating: MOT20/train/MOT20-05/img1/002901.jpg
#   inflating: MOT20/train/MOT20-05/img1/000146.jpg
#   inflating: MOT20/train/MOT20-05/img1/001239.jpg
#   inflating: MOT20/train/MOT20-05/img1/002069.jpg
#   inflating: MOT20/train/MOT20-05/img1/000010.jpg
#   inflating: MOT20/train/MOT20-05/img1/001906.jpg
#   inflating: MOT20/train/MOT20-05/img1/001019.jpg
#   inflating: MOT20/train/MOT20-05/img1/002415.jpg
#   inflating: MOT20/train/MOT20-05/img1/001361.jpg
#   inflating: MOT20/train/MOT20-05/img1/001849.jpg
#   inflating: MOT20/train/MOT20-05/img1/002268.jpg
#   inflating: MOT20/train/MOT20-05/img1/002894.jpg
#   inflating: MOT20/train/MOT20-05/img1/001118.jpg
#   inflating: MOT20/train/MOT20-05/img1/001637.jpg
#   inflating: MOT20/train/MOT20-05/img1/001838.jpg
#   inflating: MOT20/train/MOT20-05/img1/001618.jpg
#   inflating: MOT20/train/MOT20-05/img1/000229.jpg
#   inflating: MOT20/train/MOT20-05/img1/000340.jpg
#   inflating: MOT20/train/MOT20-05/img1/002373.jpg
#   inflating: MOT20/train/MOT20-05/img1/001198.jpg
#   inflating: MOT20/train/MOT20-05/img1/003015.jpg
#   inflating: MOT20/train/MOT20-05/img1/002310.jpg
#   inflating: MOT20/train/MOT20-05/img1/001610.jpg
#   inflating: MOT20/train/MOT20-05/img1/000304.jpg
#   inflating: MOT20/train/MOT20-05/img1/003036.jpg
#   inflating: MOT20/train/MOT20-05/img1/001098.jpg
#   inflating: MOT20/train/MOT20-05/img1/001581.jpg
#   inflating: MOT20/train/MOT20-05/img1/001602.jpg
#   inflating: MOT20/train/MOT20-05/img1/000467.jpg
#   inflating: MOT20/train/MOT20-05/img1/002387.jpg
#   inflating: MOT20/train/MOT20-05/img1/003064.jpg
#   inflating: MOT20/train/MOT20-05/img1/000451.jpg
#   inflating: MOT20/train/MOT20-05/img1/000246.jpg
#   inflating: MOT20/train/MOT20-05/img1/000584.jpg
#   inflating: MOT20/train/MOT20-05/img1/000077.jpg
#   inflating: MOT20/train/MOT20-05/img1/001708.jpg
#   inflating: MOT20/train/MOT20-05/img1/001463.jpg
#   inflating: MOT20/train/MOT20-05/img1/000413.jpg
#   inflating: MOT20/train/MOT20-05/img1/003106.jpg
#   inflating: MOT20/train/MOT20-05/img1/003060.jpg
#   inflating: MOT20/train/MOT20-05/img1/000818.jpg
#   inflating: MOT20/train/MOT20-05/img1/003158.jpg
#   inflating: MOT20/train/MOT20-05/img1/002933.jpg
#   inflating: MOT20/train/MOT20-05/img1/000720.jpg
#   inflating: MOT20/train/MOT20-05/img1/002598.jpg
#   inflating: MOT20/train/MOT20-05/img1/001853.jpg
#   inflating: MOT20/train/MOT20-05/img1/000129.jpg
#   inflating: MOT20/train/MOT20-05/img1/000719.jpg
#   inflating: MOT20/train/MOT20-05/img1/001592.jpg
#   inflating: MOT20/train/MOT20-05/img1/002862.jpg
#   inflating: MOT20/train/MOT20-05/img1/000006.jpg
#   inflating: MOT20/train/MOT20-05/img1/003179.jpg
#   inflating: MOT20/train/MOT20-05/img1/002067.jpg
#   inflating: MOT20/train/MOT20-05/img1/000381.jpg
#   inflating: MOT20/train/MOT20-05/img1/002409.jpg
#   inflating: MOT20/train/MOT20-05/img1/002968.jpg
#   inflating: MOT20/train/MOT20-05/img1/001280.jpg
#   inflating: MOT20/train/MOT20-05/img1/001935.jpg
#   inflating: MOT20/train/MOT20-05/img1/000548.jpg
#   inflating: MOT20/train/MOT20-05/img1/002664.jpg
#   inflating: MOT20/train/MOT20-05/img1/002857.jpg
#   inflating: MOT20/train/MOT20-05/img1/002892.jpg
#   inflating: MOT20/train/MOT20-05/img1/002792.jpg
#   inflating: MOT20/train/MOT20-05/img1/003198.jpg
#   inflating: MOT20/train/MOT20-05/img1/001792.jpg
#   inflating: MOT20/train/MOT20-05/img1/003062.jpg
#   inflating: MOT20/train/MOT20-05/img1/003067.jpg
#   inflating: MOT20/train/MOT20-05/img1/000313.jpg
#   inflating: MOT20/train/MOT20-05/img1/000291.jpg
#   inflating: MOT20/train/MOT20-05/img1/000705.jpg
#   inflating: MOT20/train/MOT20-05/img1/000279.jpg
#   inflating: MOT20/train/MOT20-05/img1/002809.jpg
#   inflating: MOT20/train/MOT20-05/img1/000043.jpg
#   inflating: MOT20/train/MOT20-05/img1/000086.jpg
#   inflating: MOT20/train/MOT20-05/img1/000216.jpg
#   inflating: MOT20/train/MOT20-05/img1/000173.jpg
#   inflating: MOT20/train/MOT20-05/img1/003221.jpg
#   inflating: MOT20/train/MOT20-05/img1/000429.jpg
#   inflating: MOT20/train/MOT20-05/img1/002115.jpg
#   inflating: MOT20/train/MOT20-05/img1/001604.jpg
#   inflating: MOT20/train/MOT20-05/img1/001799.jpg
#   inflating: MOT20/train/MOT20-05/img1/002948.jpg
#   inflating: MOT20/train/MOT20-05/img1/001522.jpg
#   inflating: MOT20/train/MOT20-05/img1/002581.jpg
#   inflating: MOT20/train/MOT20-05/img1/002619.jpg
#   inflating: MOT20/train/MOT20-05/img1/000127.jpg
#   inflating: MOT20/train/MOT20-05/img1/001986.jpg
#   inflating: MOT20/train/MOT20-05/img1/002189.jpg
#   inflating: MOT20/train/MOT20-05/img1/001751.jpg
#   inflating: MOT20/train/MOT20-05/img1/001511.jpg
#   inflating: MOT20/train/MOT20-05/img1/000201.jpg
#   inflating: MOT20/train/MOT20-05/img1/001144.jpg
#   inflating: MOT20/train/MOT20-05/img1/002437.jpg
#   inflating: MOT20/train/MOT20-05/img1/001474.jpg
#   inflating: MOT20/train/MOT20-05/img1/000356.jpg
#   inflating: MOT20/train/MOT20-05/img1/002374.jpg
#   inflating: MOT20/train/MOT20-05/img1/000174.jpg
#   inflating: MOT20/train/MOT20-05/img1/000264.jpg
#   inflating: MOT20/train/MOT20-05/img1/000930.jpg
#   inflating: MOT20/train/MOT20-05/img1/001166.jpg
#   inflating: MOT20/train/MOT20-05/img1/001167.jpg
#   inflating: MOT20/train/MOT20-05/img1/003034.jpg
#   inflating: MOT20/train/MOT20-05/img1/001135.jpg
#   inflating: MOT20/train/MOT20-05/img1/001020.jpg
#   inflating: MOT20/train/MOT20-05/img1/001893.jpg
#   inflating: MOT20/train/MOT20-05/img1/003267.jpg
#   inflating: MOT20/train/MOT20-05/img1/000109.jpg
#   inflating: MOT20/train/MOT20-05/img1/001322.jpg
#   inflating: MOT20/train/MOT20-05/img1/002540.jpg
#   inflating: MOT20/train/MOT20-05/img1/000231.jpg
#   inflating: MOT20/train/MOT20-05/img1/002535.jpg
#   inflating: MOT20/train/MOT20-05/img1/000035.jpg
#   inflating: MOT20/train/MOT20-05/img1/002060.jpg
#   inflating: MOT20/train/MOT20-05/img1/002690.jpg
#   inflating: MOT20/train/MOT20-05/img1/001431.jpg
#   inflating: MOT20/train/MOT20-05/img1/002196.jpg
#   inflating: MOT20/train/MOT20-05/img1/001017.jpg
#   inflating: MOT20/train/MOT20-05/img1/000701.jpg
#   inflating: MOT20/train/MOT20-05/img1/002138.jpg
#   inflating: MOT20/train/MOT20-05/img1/001173.jpg
#   inflating: MOT20/train/MOT20-05/img1/000976.jpg
#   inflating: MOT20/train/MOT20-05/img1/002304.jpg
#   inflating: MOT20/train/MOT20-05/img1/000648.jpg
#   inflating: MOT20/train/MOT20-05/img1/002542.jpg
#   inflating: MOT20/train/MOT20-05/img1/002219.jpg
#   inflating: MOT20/train/MOT20-05/img1/002858.jpg
#   inflating: MOT20/train/MOT20-05/img1/001392.jpg
#   inflating: MOT20/train/MOT20-05/img1/001514.jpg
#   inflating: MOT20/train/MOT20-05/img1/000432.jpg
#   inflating: MOT20/train/MOT20-05/img1/001518.jpg
#   inflating: MOT20/train/MOT20-05/img1/001048.jpg
#   inflating: MOT20/train/MOT20-05/img1/001634.jpg
#   inflating: MOT20/train/MOT20-05/img1/000589.jpg
#   inflating: MOT20/train/MOT20-05/img1/002376.jpg
#   inflating: MOT20/train/MOT20-05/img1/001630.jpg
#   inflating: MOT20/train/MOT20-05/img1/003215.jpg
#   inflating: MOT20/train/MOT20-05/img1/000888.jpg
#   inflating: MOT20/train/MOT20-05/img1/000654.jpg
#   inflating: MOT20/train/MOT20-05/img1/001244.jpg
#   inflating: MOT20/train/MOT20-05/img1/000473.jpg
#   inflating: MOT20/train/MOT20-05/img1/001506.jpg
#   inflating: MOT20/train/MOT20-05/img1/002758.jpg
#   inflating: MOT20/train/MOT20-05/img1/001442.jpg
#   inflating: MOT20/train/MOT20-05/img1/000647.jpg
#   inflating: MOT20/train/MOT20-05/img1/002280.jpg
#   inflating: MOT20/train/MOT20-05/img1/001108.jpg
#   inflating: MOT20/train/MOT20-05/img1/001083.jpg
#   inflating: MOT20/train/MOT20-05/img1/001667.jpg
#   inflating: MOT20/train/MOT20-05/img1/002713.jpg
#   inflating: MOT20/train/MOT20-05/img1/002071.jpg
#   inflating: MOT20/train/MOT20-05/img1/002334.jpg
#   inflating: MOT20/train/MOT20-05/img1/002006.jpg
#   inflating: MOT20/train/MOT20-05/img1/000562.jpg
#   inflating: MOT20/train/MOT20-05/img1/002044.jpg
#   inflating: MOT20/train/MOT20-05/img1/002477.jpg
#   inflating: MOT20/train/MOT20-05/img1/002401.jpg
#   inflating: MOT20/train/MOT20-05/img1/001672.jpg
#   inflating: MOT20/train/MOT20-05/img1/000866.jpg
#   inflating: MOT20/train/MOT20-05/img1/000569.jpg
#   inflating: MOT20/train/MOT20-05/img1/000900.jpg
#   inflating: MOT20/train/MOT20-05/img1/002216.jpg
#   inflating: MOT20/train/MOT20-05/img1/001490.jpg
#   inflating: MOT20/train/MOT20-05/img1/003073.jpg
#   inflating: MOT20/train/MOT20-05/img1/001376.jpg
#   inflating: MOT20/train/MOT20-05/img1/000343.jpg
#   inflating: MOT20/train/MOT20-05/img1/002714.jpg
#   inflating: MOT20/train/MOT20-05/img1/001674.jpg
#   inflating: MOT20/train/MOT20-05/img1/001129.jpg
#   inflating: MOT20/train/MOT20-05/img1/003141.jpg
#   inflating: MOT20/train/MOT20-05/img1/000721.jpg
#   inflating: MOT20/train/MOT20-05/img1/001659.jpg
#   inflating: MOT20/train/MOT20-05/img1/001095.jpg
#   inflating: MOT20/train/MOT20-05/img1/001947.jpg
#   inflating: MOT20/train/MOT20-05/img1/001090.jpg
#   inflating: MOT20/train/MOT20-05/img1/002778.jpg
#   inflating: MOT20/train/MOT20-05/img1/000963.jpg
#   inflating: MOT20/train/MOT20-05/img1/001760.jpg
#   inflating: MOT20/train/MOT20-05/img1/001886.jpg
#   inflating: MOT20/train/MOT20-05/img1/002505.jpg
#   inflating: MOT20/train/MOT20-05/img1/002282.jpg
#   inflating: MOT20/train/MOT20-05/img1/001926.jpg
#   inflating: MOT20/train/MOT20-05/img1/002936.jpg
#   inflating: MOT20/train/MOT20-05/img1/003007.jpg
#   inflating: MOT20/train/MOT20-05/img1/002367.jpg
#   inflating: MOT20/train/MOT20-05/img1/000553.jpg
#   inflating: MOT20/train/MOT20-05/img1/003080.jpg
#   inflating: MOT20/train/MOT20-05/img1/002609.jpg
#   inflating: MOT20/train/MOT20-05/img1/002265.jpg
#   inflating: MOT20/train/MOT20-05/img1/000586.jpg
#   inflating: MOT20/train/MOT20-05/img1/000215.jpg
#   inflating: MOT20/train/MOT20-05/img1/003217.jpg
#   inflating: MOT20/train/MOT20-05/img1/002465.jpg
#   inflating: MOT20/train/MOT20-05/img1/002574.jpg
#   inflating: MOT20/train/MOT20-05/img1/002333.jpg
#   inflating: MOT20/train/MOT20-05/img1/000673.jpg
#   inflating: MOT20/train/MOT20-05/img1/003274.jpg
#   inflating: MOT20/train/MOT20-05/img1/003225.jpg
#   inflating: MOT20/train/MOT20-05/img1/002029.jpg
#   inflating: MOT20/train/MOT20-05/img1/001357.jpg
#   inflating: MOT20/train/MOT20-05/img1/003049.jpg
#   inflating: MOT20/train/MOT20-05/img1/003077.jpg
#   inflating: MOT20/train/MOT20-05/img1/000779.jpg
#   inflating: MOT20/train/MOT20-05/img1/002211.jpg
#   inflating: MOT20/train/MOT20-05/img1/001359.jpg
#   inflating: MOT20/train/MOT20-05/img1/001253.jpg
#   inflating: MOT20/train/MOT20-05/img1/001563.jpg
#   inflating: MOT20/train/MOT20-05/img1/002712.jpg
#   inflating: MOT20/train/MOT20-05/img1/002379.jpg
#   inflating: MOT20/train/MOT20-05/img1/000072.jpg
#   inflating: MOT20/train/MOT20-05/img1/000408.jpg
#   inflating: MOT20/train/MOT20-05/img1/001690.jpg
#   inflating: MOT20/train/MOT20-05/img1/000550.jpg
#   inflating: MOT20/train/MOT20-05/img1/001608.jpg
#   inflating: MOT20/train/MOT20-05/img1/000307.jpg
#   inflating: MOT20/train/MOT20-05/img1/001642.jpg
#   inflating: MOT20/train/MOT20-05/img1/002789.jpg
#   inflating: MOT20/train/MOT20-05/img1/000377.jpg
#   inflating: MOT20/train/MOT20-05/img1/000046.jpg
#   inflating: MOT20/train/MOT20-05/img1/003236.jpg
#   inflating: MOT20/train/MOT20-05/img1/000323.jpg
#   inflating: MOT20/train/MOT20-05/img1/000464.jpg
#   inflating: MOT20/train/MOT20-05/img1/002615.jpg
#   inflating: MOT20/train/MOT20-05/img1/001561.jpg
#   inflating: MOT20/train/MOT20-05/img1/000376.jpg
#   inflating: MOT20/train/MOT20-05/img1/001354.jpg
#   inflating: MOT20/train/MOT20-05/img1/003211.jpg
#   inflating: MOT20/train/MOT20-05/img1/000328.jpg
#   inflating: MOT20/train/MOT20-05/img1/000200.jpg
#   inflating: MOT20/train/MOT20-05/img1/002749.jpg
#   inflating: MOT20/train/MOT20-05/img1/000731.jpg
#   inflating: MOT20/train/MOT20-05/img1/001034.jpg
#   inflating: MOT20/train/MOT20-05/img1/000113.jpg
#   inflating: MOT20/train/MOT20-05/img1/001880.jpg
#   inflating: MOT20/train/MOT20-05/seqinfo.ini
#    creating: MOT20/train/MOT20-05/det/
#   inflating: MOT20/train/MOT20-05/det/det.txt
#    creating: MOT20/test/
#    creating: MOT20/test/MOT20-07/
#    creating: MOT20/test/MOT20-07/img1/
#   inflating: MOT20/test/MOT20-07/img1/000152.jpg
#   inflating: MOT20/test/MOT20-07/img1/000271.jpg
#   inflating: MOT20/test/MOT20-07/img1/000329.jpg
#   inflating: MOT20/test/MOT20-07/img1/000461.jpg
#   inflating: MOT20/test/MOT20-07/img1/000023.jpg
#   inflating: MOT20/test/MOT20-07/img1/000424.jpg
#   inflating: MOT20/test/MOT20-07/img1/000039.jpg
#   inflating: MOT20/test/MOT20-07/img1/000504.jpg
#   inflating: MOT20/test/MOT20-07/img1/000064.jpg
#   inflating: MOT20/test/MOT20-07/img1/000549.jpg
#   inflating: MOT20/test/MOT20-07/img1/000492.jpg
#   inflating: MOT20/test/MOT20-07/img1/000238.jpg
#   inflating: MOT20/test/MOT20-07/img1/000448.jpg
#   inflating: MOT20/test/MOT20-07/img1/000165.jpg
#   inflating: MOT20/test/MOT20-07/img1/000119.jpg
#   inflating: MOT20/test/MOT20-07/img1/000318.jpg
#   inflating: MOT20/test/MOT20-07/img1/000455.jpg
#   inflating: MOT20/test/MOT20-07/img1/000530.jpg
#   inflating: MOT20/test/MOT20-07/img1/000435.jpg
#   inflating: MOT20/test/MOT20-07/img1/000257.jpg
#   inflating: MOT20/test/MOT20-07/img1/000132.jpg
#   inflating: MOT20/test/MOT20-07/img1/000081.jpg
#   inflating: MOT20/test/MOT20-07/img1/000151.jpg
#   inflating: MOT20/test/MOT20-07/img1/000065.jpg
#   inflating: MOT20/test/MOT20-07/img1/000117.jpg
#   inflating: MOT20/test/MOT20-07/img1/000137.jpg
#   inflating: MOT20/test/MOT20-07/img1/000275.jpg
#   inflating: MOT20/test/MOT20-07/img1/000476.jpg
#   inflating: MOT20/test/MOT20-07/img1/000013.jpg
#   inflating: MOT20/test/MOT20-07/img1/000181.jpg
#   inflating: MOT20/test/MOT20-07/img1/000079.jpg
#   inflating: MOT20/test/MOT20-07/img1/000462.jpg
#   inflating: MOT20/test/MOT20-07/img1/000478.jpg
#   inflating: MOT20/test/MOT20-07/img1/000577.jpg
#   inflating: MOT20/test/MOT20-07/img1/000078.jpg
#   inflating: MOT20/test/MOT20-07/img1/000221.jpg
#   inflating: MOT20/test/MOT20-07/img1/000193.jpg
#   inflating: MOT20/test/MOT20-07/img1/000386.jpg
#   inflating: MOT20/test/MOT20-07/img1/000130.jpg
#   inflating: MOT20/test/MOT20-07/img1/000351.jpg
#   inflating: MOT20/test/MOT20-07/img1/000063.jpg
#   inflating: MOT20/test/MOT20-07/img1/000249.jpg
#   inflating: MOT20/test/MOT20-07/img1/000284.jpg
#   inflating: MOT20/test/MOT20-07/img1/000219.jpg
#   inflating: MOT20/test/MOT20-07/img1/000419.jpg
#   inflating: MOT20/test/MOT20-07/img1/000507.jpg
#   inflating: MOT20/test/MOT20-07/img1/000331.jpg
#   inflating: MOT20/test/MOT20-07/img1/000278.jpg
#   inflating: MOT20/test/MOT20-07/img1/000333.jpg
#   inflating: MOT20/test/MOT20-07/img1/000088.jpg
#   inflating: MOT20/test/MOT20-07/img1/000105.jpg
#   inflating: MOT20/test/MOT20-07/img1/000308.jpg
#   inflating: MOT20/test/MOT20-07/img1/000346.jpg
#   inflating: MOT20/test/MOT20-07/img1/000466.jpg
#   inflating: MOT20/test/MOT20-07/img1/000326.jpg
#   inflating: MOT20/test/MOT20-07/img1/000005.jpg
#   inflating: MOT20/test/MOT20-07/img1/000337.jpg
#   inflating: MOT20/test/MOT20-07/img1/000401.jpg
#   inflating: MOT20/test/MOT20-07/img1/000334.jpg
#   inflating: MOT20/test/MOT20-07/img1/000273.jpg
#   inflating: MOT20/test/MOT20-07/img1/000295.jpg
#   inflating: MOT20/test/MOT20-07/img1/000094.jpg
#   inflating: MOT20/test/MOT20-07/img1/000202.jpg
#   inflating: MOT20/test/MOT20-07/img1/000374.jpg
#   inflating: MOT20/test/MOT20-07/img1/000156.jpg
#   inflating: MOT20/test/MOT20-07/img1/000463.jpg
#   inflating: MOT20/test/MOT20-07/img1/000211.jpg
#   inflating: MOT20/test/MOT20-07/img1/000203.jpg
#   inflating: MOT20/test/MOT20-07/img1/000349.jpg
#   inflating: MOT20/test/MOT20-07/img1/000578.jpg
#   inflating: MOT20/test/MOT20-07/img1/000533.jpg
#   inflating: MOT20/test/MOT20-07/img1/000031.jpg
#   inflating: MOT20/test/MOT20-07/img1/000433.jpg
#   inflating: MOT20/test/MOT20-07/img1/000375.jpg
#   inflating: MOT20/test/MOT20-07/img1/000112.jpg
#   inflating: MOT20/test/MOT20-07/img1/000265.jpg
#   inflating: MOT20/test/MOT20-07/img1/000366.jpg
#   inflating: MOT20/test/MOT20-07/img1/000458.jpg
#   inflating: MOT20/test/MOT20-07/img1/000069.jpg
#   inflating: MOT20/test/MOT20-07/img1/000509.jpg
#   inflating: MOT20/test/MOT20-07/img1/000501.jpg
#   inflating: MOT20/test/MOT20-07/img1/000190.jpg
#   inflating: MOT20/test/MOT20-07/img1/000443.jpg
#   inflating: MOT20/test/MOT20-07/img1/000427.jpg
#   inflating: MOT20/test/MOT20-07/img1/000520.jpg
#   inflating: MOT20/test/MOT20-07/img1/000261.jpg
#   inflating: MOT20/test/MOT20-07/img1/000258.jpg
#   inflating: MOT20/test/MOT20-07/img1/000412.jpg
#   inflating: MOT20/test/MOT20-07/img1/000330.jpg
#   inflating: MOT20/test/MOT20-07/img1/000082.jpg
#   inflating: MOT20/test/MOT20-07/img1/000370.jpg
#   inflating: MOT20/test/MOT20-07/img1/000474.jpg
#   inflating: MOT20/test/MOT20-07/img1/000289.jpg
#   inflating: MOT20/test/MOT20-07/img1/000243.jpg
#   inflating: MOT20/test/MOT20-07/img1/000256.jpg
#   inflating: MOT20/test/MOT20-07/img1/000527.jpg
#   inflating: MOT20/test/MOT20-07/img1/000025.jpg
#   inflating: MOT20/test/MOT20-07/img1/000150.jpg
#   inflating: MOT20/test/MOT20-07/img1/000206.jpg
#   inflating: MOT20/test/MOT20-07/img1/000546.jpg
#   inflating: MOT20/test/MOT20-07/img1/000084.jpg
#   inflating: MOT20/test/MOT20-07/img1/000087.jpg
#   inflating: MOT20/test/MOT20-07/img1/000163.jpg
#   inflating: MOT20/test/MOT20-07/img1/000016.jpg
#   inflating: MOT20/test/MOT20-07/img1/000228.jpg
#   inflating: MOT20/test/MOT20-07/img1/000250.jpg
#   inflating: MOT20/test/MOT20-07/img1/000528.jpg
#   inflating: MOT20/test/MOT20-07/img1/000089.jpg
#   inflating: MOT20/test/MOT20-07/img1/000363.jpg
#   inflating: MOT20/test/MOT20-07/img1/000262.jpg
#   inflating: MOT20/test/MOT20-07/img1/000204.jpg
#   inflating: MOT20/test/MOT20-07/img1/000519.jpg
#   inflating: MOT20/test/MOT20-07/img1/000167.jpg
#   inflating: MOT20/test/MOT20-07/img1/000239.jpg
#   inflating: MOT20/test/MOT20-07/img1/000175.jpg
#   inflating: MOT20/test/MOT20-07/img1/000385.jpg
#   inflating: MOT20/test/MOT20-07/img1/000247.jpg
#   inflating: MOT20/test/MOT20-07/img1/000012.jpg
#   inflating: MOT20/test/MOT20-07/img1/000392.jpg
#   inflating: MOT20/test/MOT20-07/img1/000367.jpg
#   inflating: MOT20/test/MOT20-07/img1/000218.jpg
#   inflating: MOT20/test/MOT20-07/img1/000014.jpg
#   inflating: MOT20/test/MOT20-07/img1/000075.jpg
#   inflating: MOT20/test/MOT20-07/img1/000044.jpg
#   inflating: MOT20/test/MOT20-07/img1/000309.jpg
#   inflating: MOT20/test/MOT20-07/img1/000160.jpg
#   inflating: MOT20/test/MOT20-07/img1/000133.jpg
#   inflating: MOT20/test/MOT20-07/img1/000494.jpg
#   inflating: MOT20/test/MOT20-07/img1/000141.jpg
#   inflating: MOT20/test/MOT20-07/img1/000305.jpg
#   inflating: MOT20/test/MOT20-07/img1/000052.jpg
#   inflating: MOT20/test/MOT20-07/img1/000348.jpg
#   inflating: MOT20/test/MOT20-07/img1/000058.jpg
#   inflating: MOT20/test/MOT20-07/img1/000522.jpg
#   inflating: MOT20/test/MOT20-07/img1/000153.jpg
#   inflating: MOT20/test/MOT20-07/img1/000140.jpg
#   inflating: MOT20/test/MOT20-07/img1/000403.jpg
#   inflating: MOT20/test/MOT20-07/img1/000248.jpg
#   inflating: MOT20/test/MOT20-07/img1/000068.jpg
#   inflating: MOT20/test/MOT20-07/img1/000449.jpg
#   inflating: MOT20/test/MOT20-07/img1/000047.jpg
#   inflating: MOT20/test/MOT20-07/img1/000445.jpg
#   inflating: MOT20/test/MOT20-07/img1/000495.jpg
#   inflating: MOT20/test/MOT20-07/img1/000332.jpg
#   inflating: MOT20/test/MOT20-07/img1/000521.jpg
#   inflating: MOT20/test/MOT20-07/img1/000347.jpg
#   inflating: MOT20/test/MOT20-07/img1/000285.jpg
#   inflating: MOT20/test/MOT20-07/img1/000195.jpg
#   inflating: MOT20/test/MOT20-07/img1/000294.jpg
#   inflating: MOT20/test/MOT20-07/img1/000404.jpg
#   inflating: MOT20/test/MOT20-07/img1/000542.jpg
#   inflating: MOT20/test/MOT20-07/img1/000148.jpg
#   inflating: MOT20/test/MOT20-07/img1/000484.jpg
#   inflating: MOT20/test/MOT20-07/img1/000260.jpg
#   inflating: MOT20/test/MOT20-07/img1/000470.jpg
#   inflating: MOT20/test/MOT20-07/img1/000001.jpg
#   inflating: MOT20/test/MOT20-07/img1/000060.jpg
#   inflating: MOT20/test/MOT20-07/img1/000327.jpg
#   inflating: MOT20/test/MOT20-07/img1/000324.jpg
#   inflating: MOT20/test/MOT20-07/img1/000259.jpg
#   inflating: MOT20/test/MOT20-07/img1/000496.jpg
#   inflating: MOT20/test/MOT20-07/img1/000188.jpg
#   inflating: MOT20/test/MOT20-07/img1/000021.jpg
#   inflating: MOT20/test/MOT20-07/img1/000515.jpg
#   inflating: MOT20/test/MOT20-07/img1/000382.jpg
#   inflating: MOT20/test/MOT20-07/img1/000306.jpg
#   inflating: MOT20/test/MOT20-07/img1/000131.jpg
#   inflating: MOT20/test/MOT20-07/img1/000057.jpg
#   inflating: MOT20/test/MOT20-07/img1/000480.jpg
#   inflating: MOT20/test/MOT20-07/img1/000486.jpg
#   inflating: MOT20/test/MOT20-07/img1/000489.jpg
#   inflating: MOT20/test/MOT20-07/img1/000422.jpg
#   inflating: MOT20/test/MOT20-07/img1/000444.jpg
#   inflating: MOT20/test/MOT20-07/img1/000571.jpg
#   inflating: MOT20/test/MOT20-07/img1/000311.jpg
#   inflating: MOT20/test/MOT20-07/img1/000361.jpg
#   inflating: MOT20/test/MOT20-07/img1/000409.jpg
#   inflating: MOT20/test/MOT20-07/img1/000472.jpg
#   inflating: MOT20/test/MOT20-07/img1/000293.jpg
#   inflating: MOT20/test/MOT20-07/img1/000199.jpg
#   inflating: MOT20/test/MOT20-07/img1/000198.jpg
#   inflating: MOT20/test/MOT20-07/img1/000149.jpg
#   inflating: MOT20/test/MOT20-07/img1/000468.jpg
#   inflating: MOT20/test/MOT20-07/img1/000314.jpg
#   inflating: MOT20/test/MOT20-07/img1/000108.jpg
#   inflating: MOT20/test/MOT20-07/img1/000552.jpg
#   inflating: MOT20/test/MOT20-07/img1/000513.jpg
#   inflating: MOT20/test/MOT20-07/img1/000440.jpg
#   inflating: MOT20/test/MOT20-07/img1/000142.jpg
#   inflating: MOT20/test/MOT20-07/img1/000126.jpg
#   inflating: MOT20/test/MOT20-07/img1/000482.jpg
#   inflating: MOT20/test/MOT20-07/img1/000491.jpg
#   inflating: MOT20/test/MOT20-07/img1/000319.jpg
#   inflating: MOT20/test/MOT20-07/img1/000430.jpg
#   inflating: MOT20/test/MOT20-07/img1/000189.jpg
#   inflating: MOT20/test/MOT20-07/img1/000300.jpg
#   inflating: MOT20/test/MOT20-07/img1/000280.jpg
#   inflating: MOT20/test/MOT20-07/img1/000344.jpg
#   inflating: MOT20/test/MOT20-07/img1/000358.jpg
#   inflating: MOT20/test/MOT20-07/img1/000312.jpg
#   inflating: MOT20/test/MOT20-07/img1/000268.jpg
#   inflating: MOT20/test/MOT20-07/img1/000487.jpg
#   inflating: MOT20/test/MOT20-07/img1/000076.jpg
#   inflating: MOT20/test/MOT20-07/img1/000030.jpg
#   inflating: MOT20/test/MOT20-07/img1/000028.jpg
#   inflating: MOT20/test/MOT20-07/img1/000354.jpg
#   inflating: MOT20/test/MOT20-07/img1/000003.jpg
#   inflating: MOT20/test/MOT20-07/img1/000085.jpg
#   inflating: MOT20/test/MOT20-07/img1/000095.jpg
#   inflating: MOT20/test/MOT20-07/img1/000263.jpg
#   inflating: MOT20/test/MOT20-07/img1/000045.jpg
#   inflating: MOT20/test/MOT20-07/img1/000414.jpg
#   inflating: MOT20/test/MOT20-07/img1/000106.jpg
#   inflating: MOT20/test/MOT20-07/img1/000342.jpg
#   inflating: MOT20/test/MOT20-07/img1/000282.jpg
#   inflating: MOT20/test/MOT20-07/img1/000187.jpg
#   inflating: MOT20/test/MOT20-07/img1/000048.jpg
#   inflating: MOT20/test/MOT20-07/img1/000024.jpg
#   inflating: MOT20/test/MOT20-07/img1/000037.jpg
#   inflating: MOT20/test/MOT20-07/img1/000080.jpg
#   inflating: MOT20/test/MOT20-07/img1/000456.jpg
#   inflating: MOT20/test/MOT20-07/img1/000245.jpg
#   inflating: MOT20/test/MOT20-07/img1/000180.jpg
#   inflating: MOT20/test/MOT20-07/img1/000240.jpg
#   inflating: MOT20/test/MOT20-07/img1/000446.jpg
#   inflating: MOT20/test/MOT20-07/img1/000122.jpg
#   inflating: MOT20/test/MOT20-07/img1/000574.jpg
#   inflating: MOT20/test/MOT20-07/img1/000286.jpg
#   inflating: MOT20/test/MOT20-07/img1/000526.jpg
#   inflating: MOT20/test/MOT20-07/img1/000583.jpg
#   inflating: MOT20/test/MOT20-07/img1/000303.jpg
#   inflating: MOT20/test/MOT20-07/img1/000210.jpg
#   inflating: MOT20/test/MOT20-07/img1/000074.jpg
#   inflating: MOT20/test/MOT20-07/img1/000029.jpg
#   inflating: MOT20/test/MOT20-07/img1/000032.jpg
#   inflating: MOT20/test/MOT20-07/img1/000447.jpg
#   inflating: MOT20/test/MOT20-07/img1/000352.jpg
#   inflating: MOT20/test/MOT20-07/img1/000503.jpg
#   inflating: MOT20/test/MOT20-07/img1/000556.jpg
#   inflating: MOT20/test/MOT20-07/img1/000425.jpg
#   inflating: MOT20/test/MOT20-07/img1/000036.jpg
#   inflating: MOT20/test/MOT20-07/img1/000184.jpg
#   inflating: MOT20/test/MOT20-07/img1/000483.jpg
#   inflating: MOT20/test/MOT20-07/img1/000297.jpg
#   inflating: MOT20/test/MOT20-07/img1/000566.jpg
#   inflating: MOT20/test/MOT20-07/img1/000230.jpg
#   inflating: MOT20/test/MOT20-07/img1/000582.jpg
#   inflating: MOT20/test/MOT20-07/img1/000235.jpg
#   inflating: MOT20/test/MOT20-07/img1/000345.jpg
#   inflating: MOT20/test/MOT20-07/img1/000018.jpg
#   inflating: MOT20/test/MOT20-07/img1/000070.jpg
#   inflating: MOT20/test/MOT20-07/img1/000475.jpg
#   inflating: MOT20/test/MOT20-07/img1/000555.jpg
#   inflating: MOT20/test/MOT20-07/img1/000540.jpg
#   inflating: MOT20/test/MOT20-07/img1/000177.jpg
#   inflating: MOT20/test/MOT20-07/img1/000292.jpg
#   inflating: MOT20/test/MOT20-07/img1/000071.jpg
#   inflating: MOT20/test/MOT20-07/img1/000092.jpg
#   inflating: MOT20/test/MOT20-07/img1/000525.jpg
#   inflating: MOT20/test/MOT20-07/img1/000538.jpg
#   inflating: MOT20/test/MOT20-07/img1/000083.jpg
#   inflating: MOT20/test/MOT20-07/img1/000042.jpg
#   inflating: MOT20/test/MOT20-07/img1/000179.jpg
#   inflating: MOT20/test/MOT20-07/img1/000242.jpg
#   inflating: MOT20/test/MOT20-07/img1/000341.jpg
#   inflating: MOT20/test/MOT20-07/img1/000547.jpg
#   inflating: MOT20/test/MOT20-07/img1/000107.jpg
#   inflating: MOT20/test/MOT20-07/img1/000115.jpg
#   inflating: MOT20/test/MOT20-07/img1/000485.jpg
#   inflating: MOT20/test/MOT20-07/img1/000378.jpg
#   inflating: MOT20/test/MOT20-07/img1/000254.jpg
#   inflating: MOT20/test/MOT20-07/img1/000197.jpg
#   inflating: MOT20/test/MOT20-07/img1/000116.jpg
#   inflating: MOT20/test/MOT20-07/img1/000276.jpg
#   inflating: MOT20/test/MOT20-07/img1/000428.jpg
#   inflating: MOT20/test/MOT20-07/img1/000558.jpg
#   inflating: MOT20/test/MOT20-07/img1/000479.jpg
#   inflating: MOT20/test/MOT20-07/img1/000563.jpg
#   inflating: MOT20/test/MOT20-07/img1/000267.jpg
#   inflating: MOT20/test/MOT20-07/img1/000436.jpg
#   inflating: MOT20/test/MOT20-07/img1/000405.jpg
#   inflating: MOT20/test/MOT20-07/img1/000067.jpg
#   inflating: MOT20/test/MOT20-07/img1/000099.jpg
#   inflating: MOT20/test/MOT20-07/img1/000170.jpg
#   inflating: MOT20/test/MOT20-07/img1/000208.jpg
#   inflating: MOT20/test/MOT20-07/img1/000050.jpg
#   inflating: MOT20/test/MOT20-07/img1/000209.jpg
#   inflating: MOT20/test/MOT20-07/img1/000104.jpg
#   inflating: MOT20/test/MOT20-07/img1/000002.jpg
#   inflating: MOT20/test/MOT20-07/img1/000402.jpg
#   inflating: MOT20/test/MOT20-07/img1/000431.jpg
#   inflating: MOT20/test/MOT20-07/img1/000144.jpg
#   inflating: MOT20/test/MOT20-07/img1/000338.jpg
#   inflating: MOT20/test/MOT20-07/img1/000575.jpg
#   inflating: MOT20/test/MOT20-07/img1/000121.jpg
#   inflating: MOT20/test/MOT20-07/img1/000034.jpg
#   inflating: MOT20/test/MOT20-07/img1/000580.jpg
#   inflating: MOT20/test/MOT20-07/img1/000176.jpg
#   inflating: MOT20/test/MOT20-07/img1/000477.jpg
#   inflating: MOT20/test/MOT20-07/img1/000434.jpg
#   inflating: MOT20/test/MOT20-07/img1/000369.jpg
#   inflating: MOT20/test/MOT20-07/img1/000272.jpg
#   inflating: MOT20/test/MOT20-07/img1/000093.jpg
#   inflating: MOT20/test/MOT20-07/img1/000535.jpg
#   inflating: MOT20/test/MOT20-07/img1/000415.jpg
#   inflating: MOT20/test/MOT20-07/img1/000274.jpg
#   inflating: MOT20/test/MOT20-07/img1/000033.jpg
#   inflating: MOT20/test/MOT20-07/img1/000516.jpg
#   inflating: MOT20/test/MOT20-07/img1/000508.jpg
#   inflating: MOT20/test/MOT20-07/img1/000490.jpg
#   inflating: MOT20/test/MOT20-07/img1/000008.jpg
#   inflating: MOT20/test/MOT20-07/img1/000061.jpg
#   inflating: MOT20/test/MOT20-07/img1/000511.jpg
#   inflating: MOT20/test/MOT20-07/img1/000407.jpg
#   inflating: MOT20/test/MOT20-07/img1/000054.jpg
#   inflating: MOT20/test/MOT20-07/img1/000103.jpg
#   inflating: MOT20/test/MOT20-07/img1/000134.jpg
#   inflating: MOT20/test/MOT20-07/img1/000310.jpg
#   inflating: MOT20/test/MOT20-07/img1/000241.jpg
#   inflating: MOT20/test/MOT20-07/img1/000299.jpg
#   inflating: MOT20/test/MOT20-07/img1/000154.jpg
#   inflating: MOT20/test/MOT20-07/img1/000524.jpg
#   inflating: MOT20/test/MOT20-07/img1/000400.jpg
#   inflating: MOT20/test/MOT20-07/img1/000269.jpg
#   inflating: MOT20/test/MOT20-07/img1/000518.jpg
#   inflating: MOT20/test/MOT20-07/img1/000336.jpg
#   inflating: MOT20/test/MOT20-07/img1/000572.jpg
#   inflating: MOT20/test/MOT20-07/img1/000379.jpg
#   inflating: MOT20/test/MOT20-07/img1/000213.jpg
#   inflating: MOT20/test/MOT20-07/img1/000573.jpg
#   inflating: MOT20/test/MOT20-07/img1/000383.jpg
#   inflating: MOT20/test/MOT20-07/img1/000570.jpg
#   inflating: MOT20/test/MOT20-07/img1/000220.jpg
#   inflating: MOT20/test/MOT20-07/img1/000441.jpg
#   inflating: MOT20/test/MOT20-07/img1/000027.jpg
#   inflating: MOT20/test/MOT20-07/img1/000009.jpg
#   inflating: MOT20/test/MOT20-07/img1/000426.jpg
#   inflating: MOT20/test/MOT20-07/img1/000227.jpg
#   inflating: MOT20/test/MOT20-07/img1/000224.jpg
#   inflating: MOT20/test/MOT20-07/img1/000497.jpg
#   inflating: MOT20/test/MOT20-07/img1/000135.jpg
#   inflating: MOT20/test/MOT20-07/img1/000138.jpg
#   inflating: MOT20/test/MOT20-07/img1/000568.jpg
#   inflating: MOT20/test/MOT20-07/img1/000389.jpg
#   inflating: MOT20/test/MOT20-07/img1/000380.jpg
#   inflating: MOT20/test/MOT20-07/img1/000128.jpg
#   inflating: MOT20/test/MOT20-07/img1/000277.jpg
#   inflating: MOT20/test/MOT20-07/img1/000537.jpg
#   inflating: MOT20/test/MOT20-07/img1/000011.jpg
#   inflating: MOT20/test/MOT20-07/img1/000438.jpg
#   inflating: MOT20/test/MOT20-07/img1/000544.jpg
#   inflating: MOT20/test/MOT20-07/img1/000384.jpg
#   inflating: MOT20/test/MOT20-07/img1/000493.jpg
#   inflating: MOT20/test/MOT20-07/img1/000416.jpg
#   inflating: MOT20/test/MOT20-07/img1/000450.jpg
#   inflating: MOT20/test/MOT20-07/img1/000017.jpg
#   inflating: MOT20/test/MOT20-07/img1/000564.jpg
#   inflating: MOT20/test/MOT20-07/img1/000225.jpg
#   inflating: MOT20/test/MOT20-07/img1/000398.jpg
#   inflating: MOT20/test/MOT20-07/img1/000423.jpg
#   inflating: MOT20/test/MOT20-07/img1/000315.jpg
#   inflating: MOT20/test/MOT20-07/img1/000359.jpg
#   inflating: MOT20/test/MOT20-07/img1/000362.jpg
#   inflating: MOT20/test/MOT20-07/img1/000517.jpg
#   inflating: MOT20/test/MOT20-07/img1/000437.jpg
#   inflating: MOT20/test/MOT20-07/img1/000372.jpg
#   inflating: MOT20/test/MOT20-07/img1/000505.jpg
#   inflating: MOT20/test/MOT20-07/img1/000096.jpg
#   inflating: MOT20/test/MOT20-07/img1/000388.jpg
#   inflating: MOT20/test/MOT20-07/img1/000581.jpg
#   inflating: MOT20/test/MOT20-07/img1/000015.jpg
#   inflating: MOT20/test/MOT20-07/img1/000091.jpg
#   inflating: MOT20/test/MOT20-07/img1/000205.jpg
#   inflating: MOT20/test/MOT20-07/img1/000565.jpg
#   inflating: MOT20/test/MOT20-07/img1/000471.jpg
#   inflating: MOT20/test/MOT20-07/img1/000147.jpg
#   inflating: MOT20/test/MOT20-07/img1/000502.jpg
#   inflating: MOT20/test/MOT20-07/img1/000183.jpg
#   inflating: MOT20/test/MOT20-07/img1/000585.jpg
#   inflating: MOT20/test/MOT20-07/img1/000410.jpg
#   inflating: MOT20/test/MOT20-07/img1/000543.jpg
#   inflating: MOT20/test/MOT20-07/img1/000161.jpg
#   inflating: MOT20/test/MOT20-07/img1/000316.jpg
#   inflating: MOT20/test/MOT20-07/img1/000214.jpg
#   inflating: MOT20/test/MOT20-07/img1/000417.jpg
#   inflating: MOT20/test/MOT20-07/img1/000397.jpg
#   inflating: MOT20/test/MOT20-07/img1/000004.jpg
#   inflating: MOT20/test/MOT20-07/img1/000255.jpg
#   inflating: MOT20/test/MOT20-07/img1/000406.jpg
#   inflating: MOT20/test/MOT20-07/img1/000395.jpg
#   inflating: MOT20/test/MOT20-07/img1/000123.jpg
#   inflating: MOT20/test/MOT20-07/img1/000073.jpg
#   inflating: MOT20/test/MOT20-07/img1/000055.jpg
#   inflating: MOT20/test/MOT20-07/img1/000454.jpg
#   inflating: MOT20/test/MOT20-07/img1/000364.jpg
#   inflating: MOT20/test/MOT20-07/img1/000523.jpg
#   inflating: MOT20/test/MOT20-07/img1/000253.jpg
#   inflating: MOT20/test/MOT20-07/img1/000019.jpg
#   inflating: MOT20/test/MOT20-07/img1/000322.jpg
#   inflating: MOT20/test/MOT20-07/img1/000056.jpg
#   inflating: MOT20/test/MOT20-07/img1/000339.jpg
#   inflating: MOT20/test/MOT20-07/img1/000007.jpg
#   inflating: MOT20/test/MOT20-07/img1/000317.jpg
#   inflating: MOT20/test/MOT20-07/img1/000394.jpg
#   inflating: MOT20/test/MOT20-07/img1/000053.jpg
#   inflating: MOT20/test/MOT20-07/img1/000290.jpg
#   inflating: MOT20/test/MOT20-07/img1/000453.jpg
#   inflating: MOT20/test/MOT20-07/img1/000335.jpg
#   inflating: MOT20/test/MOT20-07/img1/000162.jpg
#   inflating: MOT20/test/MOT20-07/img1/000266.jpg
#   inflating: MOT20/test/MOT20-07/img1/000049.jpg
#   inflating: MOT20/test/MOT20-07/img1/000418.jpg
#   inflating: MOT20/test/MOT20-07/img1/000373.jpg
#   inflating: MOT20/test/MOT20-07/img1/000459.jpg
#   inflating: MOT20/test/MOT20-07/img1/000171.jpg
#   inflating: MOT20/test/MOT20-07/img1/000182.jpg
#   inflating: MOT20/test/MOT20-07/img1/000514.jpg
#   inflating: MOT20/test/MOT20-07/img1/000452.jpg
#   inflating: MOT20/test/MOT20-07/img1/000439.jpg
#   inflating: MOT20/test/MOT20-07/img1/000223.jpg
#   inflating: MOT20/test/MOT20-07/img1/000157.jpg
#   inflating: MOT20/test/MOT20-07/img1/000536.jpg
#   inflating: MOT20/test/MOT20-07/img1/000559.jpg
#   inflating: MOT20/test/MOT20-07/img1/000251.jpg
#   inflating: MOT20/test/MOT20-07/img1/000545.jpg
#   inflating: MOT20/test/MOT20-07/img1/000178.jpg
#   inflating: MOT20/test/MOT20-07/img1/000234.jpg
#   inflating: MOT20/test/MOT20-07/img1/000298.jpg
# ...
#   inflating: MOT20/test/MOT20-04/img1/002020.jpg
#   inflating: MOT20/test/MOT20-04/img1/001247.jpg
#   inflating: MOT20/test/MOT20-04/img1/001419.jpg
#   inflating: MOT20/test/MOT20-04/img1/001644.jpg
#   inflating: MOT20/test/MOT20-04/img1/000783.jpg
#   inflating: MOT20/test/MOT20-04/img1/000499.jpg
#   inflating: MOT20/test/MOT20-04/img1/001774.jpg
#   inflating: MOT20/test/MOT20-04/img1/000143.jpg
#   inflating: MOT20/test/MOT20-04/img1/001624.jpg
#   inflating: MOT20/test/MOT20-04/img1/001078.jpg
#   inflating: MOT20/test/MOT20-04/img1/001613.jpg
#   inflating: MOT20/test/MOT20-04/img1/001921.jpg
#   inflating: MOT20/test/MOT20-04/img1/001696.jpg
#   inflating: MOT20/test/MOT20-04/img1/000411.jpg
#   inflating: MOT20/test/MOT20-04/img1/001530.jpg
#   inflating: MOT20/test/MOT20-04/img1/000829.jpg
#   inflating: MOT20/test/MOT20-04/img1/001955.jpg
#   inflating: MOT20/test/MOT20-04/img1/001969.jpg
#   inflating: MOT20/test/MOT20-04/img1/001201.jpg
#   inflating: MOT20/test/MOT20-04/img1/002023.jpg
#   inflating: MOT20/test/MOT20-04/img1/001996.jpg
#   inflating: MOT20/test/MOT20-04/img1/001944.jpg
#   inflating: MOT20/test/MOT20-04/img1/000529.jpg
#   inflating: MOT20/test/MOT20-04/img1/001870.jpg
#   inflating: MOT20/test/MOT20-04/img1/000592.jpg
#   inflating: MOT20/test/MOT20-04/img1/001549.jpg
#   inflating: MOT20/test/MOT20-04/img1/001949.jpg
#   inflating: MOT20/test/MOT20-04/img1/000730.jpg
#   inflating: MOT20/test/MOT20-04/img1/001159.jpg
#   inflating: MOT20/test/MOT20-04/img1/000111.jpg
#   inflating: MOT20/test/MOT20-04/img1/001535.jpg
#   inflating: MOT20/test/MOT20-04/img1/000969.jpg
#   inflating: MOT20/test/MOT20-04/img1/000270.jpg
#   inflating: MOT20/test/MOT20-04/img1/000805.jpg
#   inflating: MOT20/test/MOT20-04/img1/001752.jpg
#   inflating: MOT20/test/MOT20-04/img1/001124.jpg
#   inflating: MOT20/test/MOT20-04/img1/001748.jpg
#   inflating: MOT20/test/MOT20-04/img1/001332.jpg
#   inflating: MOT20/test/MOT20-04/img1/001114.jpg
#   inflating: MOT20/test/MOT20-04/img1/000101.jpg
#   inflating: MOT20/test/MOT20-04/img1/001704.jpg
#   inflating: MOT20/test/MOT20-04/img1/000958.jpg
#   inflating: MOT20/test/MOT20-04/img1/001227.jpg
#   inflating: MOT20/test/MOT20-04/img1/000207.jpg
#   inflating: MOT20/test/MOT20-04/img1/001053.jpg
#   inflating: MOT20/test/MOT20-04/img1/000876.jpg
#   inflating: MOT20/test/MOT20-04/img1/000469.jpg
#   inflating: MOT20/test/MOT20-04/img1/000498.jpg
#   inflating: MOT20/test/MOT20-04/img1/000599.jpg
#   inflating: MOT20/test/MOT20-04/img1/002036.jpg
#   inflating: MOT20/test/MOT20-04/img1/001025.jpg
#   inflating: MOT20/test/MOT20-04/img1/001619.jpg
#   inflating: MOT20/test/MOT20-04/img1/000226.jpg
#   inflating: MOT20/test/MOT20-04/img1/002046.jpg
#   inflating: MOT20/test/MOT20-04/img1/000898.jpg
#   inflating: MOT20/test/MOT20-04/img1/001692.jpg
#   inflating: MOT20/test/MOT20-04/img1/000608.jpg
#   inflating: MOT20/test/MOT20-04/img1/001643.jpg
#   inflating: MOT20/test/MOT20-04/img1/000991.jpg
#   inflating: MOT20/test/MOT20-04/img1/000062.jpg
#   inflating: MOT20/test/MOT20-04/img1/000611.jpg
#   inflating: MOT20/test/MOT20-04/img1/000232.jpg
#   inflating: MOT20/test/MOT20-04/img1/000041.jpg
#   inflating: MOT20/test/MOT20-04/img1/001686.jpg
#   inflating: MOT20/test/MOT20-04/img1/000539.jpg
#   inflating: MOT20/test/MOT20-04/img1/001008.jpg
#   inflating: MOT20/test/MOT20-04/img1/001574.jpg
#   inflating: MOT20/test/MOT20-04/img1/000880.jpg
#   inflating: MOT20/test/MOT20-04/img1/001031.jpg
#   inflating: MOT20/test/MOT20-04/img1/000212.jpg
#   inflating: MOT20/test/MOT20-04/img1/000022.jpg
#   inflating: MOT20/test/MOT20-04/img1/000759.jpg
#   inflating: MOT20/test/MOT20-04/img1/001504.jpg
#   inflating: MOT20/test/MOT20-04/img1/000287.jpg
#   inflating: MOT20/test/MOT20-04/img1/001261.jpg
#   inflating: MOT20/test/MOT20-04/img1/001848.jpg
#   inflating: MOT20/test/MOT20-04/img1/001046.jpg
#   inflating: MOT20/test/MOT20-04/img1/000753.jpg
#   inflating: MOT20/test/MOT20-04/img1/001029.jpg
#   inflating: MOT20/test/MOT20-04/img1/001495.jpg
#   inflating: MOT20/test/MOT20-04/img1/000097.jpg
#   inflating: MOT20/test/MOT20-04/img1/001224.jpg
#   inflating: MOT20/test/MOT20-04/img1/000628.jpg
#   inflating: MOT20/test/MOT20-04/img1/001655.jpg
#   inflating: MOT20/test/MOT20-04/img1/001605.jpg
#   inflating: MOT20/test/MOT20-04/img1/001374.jpg
#   inflating: MOT20/test/MOT20-04/img1/000368.jpg
#   inflating: MOT20/test/MOT20-04/img1/000090.jpg
#   inflating: MOT20/test/MOT20-04/img1/000321.jpg
#   inflating: MOT20/test/MOT20-04/img1/001778.jpg
#   inflating: MOT20/test/MOT20-04/img1/000302.jpg
#   inflating: MOT20/test/MOT20-04/img1/001628.jpg
#   inflating: MOT20/test/MOT20-04/img1/001956.jpg
#   inflating: MOT20/test/MOT20-04/img1/000510.jpg
#   inflating: MOT20/test/MOT20-04/img1/001544.jpg
#   inflating: MOT20/test/MOT20-04/img1/000561.jpg
#   inflating: MOT20/test/MOT20-04/img1/000371.jpg
#   inflating: MOT20/test/MOT20-04/img1/001562.jpg
#   inflating: MOT20/test/MOT20-04/img1/000629.jpg
#   inflating: MOT20/test/MOT20-04/img1/000884.jpg
#   inflating: MOT20/test/MOT20-04/img1/000901.jpg
#   inflating: MOT20/test/MOT20-04/img1/002038.jpg
#   inflating: MOT20/test/MOT20-04/img1/000051.jpg
#   inflating: MOT20/test/MOT20-04/img1/000393.jpg
#   inflating: MOT20/test/MOT20-04/img1/000296.jpg
#   inflating: MOT20/test/MOT20-04/img1/001513.jpg
#   inflating: MOT20/test/MOT20-04/img1/001739.jpg
#   inflating: MOT20/test/MOT20-04/img1/001888.jpg
#   inflating: MOT20/test/MOT20-04/img1/000288.jpg
#   inflating: MOT20/test/MOT20-04/img1/001087.jpg
#   inflating: MOT20/test/MOT20-04/img1/001966.jpg
#   inflating: MOT20/test/MOT20-04/img1/001349.jpg
#   inflating: MOT20/test/MOT20-04/img1/000995.jpg
#   inflating: MOT20/test/MOT20-04/img1/001218.jpg
#   inflating: MOT20/test/MOT20-04/img1/000155.jpg
#   inflating: MOT20/test/MOT20-04/img1/000158.jpg
#   inflating: MOT20/test/MOT20-04/img1/000442.jpg
#   inflating: MOT20/test/MOT20-04/img1/000970.jpg
#   inflating: MOT20/test/MOT20-04/img1/001405.jpg
#   inflating: MOT20/test/MOT20-04/img1/000634.jpg
#   inflating: MOT20/test/MOT20-04/img1/000145.jpg
#   inflating: MOT20/test/MOT20-04/img1/001225.jpg
#   inflating: MOT20/test/MOT20-04/img1/002018.jpg
#   inflating: MOT20/test/MOT20-04/img1/001801.jpg
#   inflating: MOT20/test/MOT20-04/img1/000631.jpg
#   inflating: MOT20/test/MOT20-04/img1/001727.jpg
#   inflating: MOT20/test/MOT20-04/img1/000892.jpg
#   inflating: MOT20/test/MOT20-04/img1/000506.jpg
#   inflating: MOT20/test/MOT20-04/img1/000579.jpg
#   inflating: MOT20/test/MOT20-04/img1/000620.jpg
#   inflating: MOT20/test/MOT20-04/img1/001766.jpg
#   inflating: MOT20/test/MOT20-04/img1/001854.jpg
#   inflating: MOT20/test/MOT20-04/img1/000733.jpg
#   inflating: MOT20/test/MOT20-04/img1/001965.jpg
#   inflating: MOT20/test/MOT20-04/img1/001291.jpg
#   inflating: MOT20/test/MOT20-04/img1/001934.jpg
#   inflating: MOT20/test/MOT20-04/img1/002025.jpg
#   inflating: MOT20/test/MOT20-04/img1/000927.jpg
#   inflating: MOT20/test/MOT20-04/img1/000840.jpg
#   inflating: MOT20/test/MOT20-04/img1/001320.jpg
#   inflating: MOT20/test/MOT20-04/img1/001941.jpg
#   inflating: MOT20/test/MOT20-04/img1/000832.jpg
#   inflating: MOT20/test/MOT20-04/img1/001281.jpg
#   inflating: MOT20/test/MOT20-04/img1/002050.jpg
#   inflating: MOT20/test/MOT20-04/img1/000066.jpg
#   inflating: MOT20/test/MOT20-04/img1/001241.jpg
#   inflating: MOT20/test/MOT20-04/img1/001617.jpg
#   inflating: MOT20/test/MOT20-04/img1/000624.jpg
#   inflating: MOT20/test/MOT20-04/img1/001916.jpg
#   inflating: MOT20/test/MOT20-04/img1/001319.jpg
#   inflating: MOT20/test/MOT20-04/img1/001878.jpg
#   inflating: MOT20/test/MOT20-04/img1/001904.jpg
#   inflating: MOT20/test/MOT20-04/img1/000754.jpg
#   inflating: MOT20/test/MOT20-04/img1/000192.jpg
#   inflating: MOT20/test/MOT20-04/img1/001695.jpg
#   inflating: MOT20/test/MOT20-04/img1/000120.jpg
#   inflating: MOT20/test/MOT20-04/img1/002022.jpg
#   inflating: MOT20/test/MOT20-04/img1/000567.jpg
#   inflating: MOT20/test/MOT20-04/img1/002030.jpg
#   inflating: MOT20/test/MOT20-04/img1/001449.jpg
#   inflating: MOT20/test/MOT20-04/img1/001152.jpg
#   inflating: MOT20/test/MOT20-04/img1/000146.jpg
#   inflating: MOT20/test/MOT20-04/img1/001239.jpg
#   inflating: MOT20/test/MOT20-04/img1/002069.jpg
#   inflating: MOT20/test/MOT20-04/img1/000010.jpg
#   inflating: MOT20/test/MOT20-04/img1/001906.jpg
#   inflating: MOT20/test/MOT20-04/img1/001019.jpg
#   inflating: MOT20/test/MOT20-04/img1/001361.jpg
#   inflating: MOT20/test/MOT20-04/img1/001849.jpg
#   inflating: MOT20/test/MOT20-04/img1/001118.jpg
#   inflating: MOT20/test/MOT20-04/img1/001637.jpg
#   inflating: MOT20/test/MOT20-04/img1/001838.jpg
#   inflating: MOT20/test/MOT20-04/img1/001618.jpg
#   inflating: MOT20/test/MOT20-04/img1/000229.jpg
#   inflating: MOT20/test/MOT20-04/img1/000340.jpg
#   inflating: MOT20/test/MOT20-04/img1/001198.jpg
#   inflating: MOT20/test/MOT20-04/img1/001610.jpg
#   inflating: MOT20/test/MOT20-04/img1/000304.jpg
#   inflating: MOT20/test/MOT20-04/img1/001098.jpg
#   inflating: MOT20/test/MOT20-04/img1/001581.jpg
#   inflating: MOT20/test/MOT20-04/img1/001602.jpg
#   inflating: MOT20/test/MOT20-04/img1/000467.jpg
#   inflating: MOT20/test/MOT20-04/img1/000451.jpg
#   inflating: MOT20/test/MOT20-04/img1/000246.jpg
#   inflating: MOT20/test/MOT20-04/img1/000584.jpg
#   inflating: MOT20/test/MOT20-04/img1/000077.jpg
#   inflating: MOT20/test/MOT20-04/img1/001708.jpg
#   inflating: MOT20/test/MOT20-04/img1/001463.jpg
#   inflating: MOT20/test/MOT20-04/img1/000413.jpg
#   inflating: MOT20/test/MOT20-04/img1/000818.jpg
#   inflating: MOT20/test/MOT20-04/img1/000720.jpg
#   inflating: MOT20/test/MOT20-04/img1/001853.jpg
#   inflating: MOT20/test/MOT20-04/img1/000129.jpg
#   inflating: MOT20/test/MOT20-04/img1/000719.jpg
#   inflating: MOT20/test/MOT20-04/img1/001592.jpg
#   inflating: MOT20/test/MOT20-04/img1/000006.jpg
#   inflating: MOT20/test/MOT20-04/img1/002067.jpg
#   inflating: MOT20/test/MOT20-04/img1/000381.jpg
#   inflating: MOT20/test/MOT20-04/img1/001280.jpg
#   inflating: MOT20/test/MOT20-04/img1/001935.jpg
#   inflating: MOT20/test/MOT20-04/img1/000548.jpg
#   inflating: MOT20/test/MOT20-04/img1/001792.jpg
#   inflating: MOT20/test/MOT20-04/img1/000313.jpg
#   inflating: MOT20/test/MOT20-04/img1/000291.jpg
#   inflating: MOT20/test/MOT20-04/img1/000705.jpg
#   inflating: MOT20/test/MOT20-04/img1/000279.jpg
#   inflating: MOT20/test/MOT20-04/img1/000043.jpg
#   inflating: MOT20/test/MOT20-04/img1/000086.jpg
#   inflating: MOT20/test/MOT20-04/img1/000216.jpg
#   inflating: MOT20/test/MOT20-04/img1/000173.jpg
#   inflating: MOT20/test/MOT20-04/img1/000429.jpg
#   inflating: MOT20/test/MOT20-04/img1/001604.jpg
#   inflating: MOT20/test/MOT20-04/img1/001799.jpg
#   inflating: MOT20/test/MOT20-04/img1/001522.jpg
#   inflating: MOT20/test/MOT20-04/img1/000127.jpg
#   inflating: MOT20/test/MOT20-04/img1/001986.jpg
#   inflating: MOT20/test/MOT20-04/img1/001751.jpg
#   inflating: MOT20/test/MOT20-04/img1/001511.jpg
#   inflating: MOT20/test/MOT20-04/img1/000201.jpg
#   inflating: MOT20/test/MOT20-04/img1/001144.jpg
#   inflating: MOT20/test/MOT20-04/img1/001474.jpg
#   inflating: MOT20/test/MOT20-04/img1/000356.jpg
#   inflating: MOT20/test/MOT20-04/img1/000174.jpg
#   inflating: MOT20/test/MOT20-04/img1/000264.jpg
#   inflating: MOT20/test/MOT20-04/img1/000930.jpg
#   inflating: MOT20/test/MOT20-04/img1/001166.jpg
#   inflating: MOT20/test/MOT20-04/img1/001167.jpg
#   inflating: MOT20/test/MOT20-04/img1/001135.jpg
#   inflating: MOT20/test/MOT20-04/img1/001020.jpg
#   inflating: MOT20/test/MOT20-04/img1/001893.jpg
#   inflating: MOT20/test/MOT20-04/img1/000109.jpg
#   inflating: MOT20/test/MOT20-04/img1/001322.jpg
#   inflating: MOT20/test/MOT20-04/img1/000231.jpg
#   inflating: MOT20/test/MOT20-04/img1/000035.jpg
#   inflating: MOT20/test/MOT20-04/img1/002060.jpg
#   inflating: MOT20/test/MOT20-04/img1/001431.jpg
#   inflating: MOT20/test/MOT20-04/img1/001017.jpg
#   inflating: MOT20/test/MOT20-04/img1/000701.jpg
#   inflating: MOT20/test/MOT20-04/img1/001173.jpg
#   inflating: MOT20/test/MOT20-04/img1/000976.jpg
#   inflating: MOT20/test/MOT20-04/img1/000648.jpg
#   inflating: MOT20/test/MOT20-04/img1/001392.jpg
#   inflating: MOT20/test/MOT20-04/img1/001514.jpg
#   inflating: MOT20/test/MOT20-04/img1/000432.jpg
#   inflating: MOT20/test/MOT20-04/img1/001518.jpg
#   inflating: MOT20/test/MOT20-04/img1/001048.jpg
#   inflating: MOT20/test/MOT20-04/img1/001634.jpg
#   inflating: MOT20/test/MOT20-04/img1/000589.jpg
#   inflating: MOT20/test/MOT20-04/img1/001630.jpg
#   inflating: MOT20/test/MOT20-04/img1/000888.jpg
#   inflating: MOT20/test/MOT20-04/img1/000654.jpg
#   inflating: MOT20/test/MOT20-04/img1/001244.jpg
#   inflating: MOT20/test/MOT20-04/img1/000473.jpg
#   inflating: MOT20/test/MOT20-04/img1/001506.jpg
#   inflating: MOT20/test/MOT20-04/img1/001442.jpg
#   inflating: MOT20/test/MOT20-04/img1/000647.jpg
#   inflating: MOT20/test/MOT20-04/img1/001108.jpg
#   inflating: MOT20/test/MOT20-04/img1/001083.jpg
#   inflating: MOT20/test/MOT20-04/img1/001667.jpg
#   inflating: MOT20/test/MOT20-04/img1/002071.jpg
#   inflating: MOT20/test/MOT20-04/img1/002006.jpg
#   inflating: MOT20/test/MOT20-04/img1/000562.jpg
#   inflating: MOT20/test/MOT20-04/img1/002044.jpg
#   inflating: MOT20/test/MOT20-04/img1/001672.jpg
#   inflating: MOT20/test/MOT20-04/img1/000866.jpg
#   inflating: MOT20/test/MOT20-04/img1/000569.jpg
#   inflating: MOT20/test/MOT20-04/img1/000900.jpg
#   inflating: MOT20/test/MOT20-04/img1/001490.jpg
#   inflating: MOT20/test/MOT20-04/img1/001376.jpg
#   inflating: MOT20/test/MOT20-04/img1/000343.jpg
#   inflating: MOT20/test/MOT20-04/img1/001674.jpg
#   inflating: MOT20/test/MOT20-04/img1/001129.jpg
#   inflating: MOT20/test/MOT20-04/img1/000721.jpg
#   inflating: MOT20/test/MOT20-04/img1/001659.jpg
#   inflating: MOT20/test/MOT20-04/img1/001095.jpg
#   inflating: MOT20/test/MOT20-04/img1/001947.jpg
#   inflating: MOT20/test/MOT20-04/img1/001090.jpg
#   inflating: MOT20/test/MOT20-04/img1/000963.jpg
#   inflating: MOT20/test/MOT20-04/img1/001760.jpg
#   inflating: MOT20/test/MOT20-04/img1/001886.jpg
#   inflating: MOT20/test/MOT20-04/img1/001926.jpg
#   inflating: MOT20/test/MOT20-04/img1/000553.jpg
#   inflating: MOT20/test/MOT20-04/img1/000586.jpg
#   inflating: MOT20/test/MOT20-04/img1/000215.jpg
#   inflating: MOT20/test/MOT20-04/img1/000673.jpg
#   inflating: MOT20/test/MOT20-04/img1/002029.jpg
#   inflating: MOT20/test/MOT20-04/img1/001357.jpg
#   inflating: MOT20/test/MOT20-04/img1/000779.jpg
#   inflating: MOT20/test/MOT20-04/img1/001359.jpg
#   inflating: MOT20/test/MOT20-04/img1/001253.jpg
#   inflating: MOT20/test/MOT20-04/img1/001563.jpg
#   inflating: MOT20/test/MOT20-04/img1/000072.jpg
#   inflating: MOT20/test/MOT20-04/img1/000408.jpg
#   inflating: MOT20/test/MOT20-04/img1/001690.jpg
#   inflating: MOT20/test/MOT20-04/img1/000550.jpg
#   inflating: MOT20/test/MOT20-04/img1/001608.jpg
#   inflating: MOT20/test/MOT20-04/img1/000307.jpg
#   inflating: MOT20/test/MOT20-04/img1/001642.jpg
#   inflating: MOT20/test/MOT20-04/img1/000377.jpg
#   inflating: MOT20/test/MOT20-04/img1/000046.jpg
#   inflating: MOT20/test/MOT20-04/img1/000323.jpg
#   inflating: MOT20/test/MOT20-04/img1/000464.jpg
#   inflating: MOT20/test/MOT20-04/img1/001561.jpg
#   inflating: MOT20/test/MOT20-04/img1/000376.jpg
#   inflating: MOT20/test/MOT20-04/img1/001354.jpg
#   inflating: MOT20/test/MOT20-04/img1/000328.jpg
#   inflating: MOT20/test/MOT20-04/img1/000200.jpg
#   inflating: MOT20/test/MOT20-04/img1/000731.jpg
#   inflating: MOT20/test/MOT20-04/img1/001034.jpg
#   inflating: MOT20/test/MOT20-04/img1/000113.jpg
#   inflating: MOT20/test/MOT20-04/img1/001880.jpg
#   inflating: MOT20/test/MOT20-04/seqinfo.ini
#    creating: MOT20/test/MOT20-04/det/
#   inflating: MOT20/test/MOT20-04/det/det.txt

# %%
# %cd /content/drive/MyDrive/Viettel DTalent/ViettelTalentsPhase2/Phan Nhật Minh/track_v2
# Out:
# /content/drive/.shortcut-targets-by-id/1EByIwlziiqlpOeuKZ73vahMuc1cs8u1e/ViettelTalentsPhase2/Phan Nhật Minh/track_v2

# %%
# !pip install hungarian-algorithm
# Out:
# Collecting hungarian-algorithm
#   Downloading hungarian_algorithm-0.1.11-py3-none-any.whl (10 kB)
# Installing collected packages: hungarian-algorithm
# Successfully installed hungarian-algorithm-0.1.11

# %%
# %load_ext autoreload
# %autoreload 2

import argparse
from collections import OrderedDict, deque, defaultdict
import copy
import cv2
from cv2 import CAP_PROP_FRAME_COUNT
import dask
import glob
from hungarian_algorithm import algorithm
import numpy as np
from numpy import random
from numpy.linalg import norm
import os
from tqdm import tqdm
import time
from pathlib import Path
import pickle
from PIL.Image import Image
from scipy.optimize import linear_sum_assignment
from scipy.spatial import distance_matrix
import statistics
import shutil
import toolz

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import sys
sys.path.insert(0, 'yolov5/')

from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages, letterbox
from utils.general import check_img_size, check_requirements, check_imshow, non_max_suppression, apply_classifier, \
    scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
from utils.plots import plot_one_box
from utils.torch_utils import select_device, load_classifier, time_synchronized
from detectObj_for_Tracking import detectFromImage
from reid_new.vehicle_embedder import VehicleEmbedder

# %%
class dotdict(dict):
    """ dot.notation access to dictionary attributes """
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

# %%
# %ls
# Out:
# datasets/  notebooks/  output/  reid/  reid_new/  weights/  yolov5/

# %%
class DataCFG:
    n_id = 400
    window_size = 10

# %%
class Logger:
    def __init__(self, path):
        self.f = open(path, 'w')
        self._n_det = 0
        self._n_track = 0
        self._t_det = 0
        self._t_reid = 0
        self._t_euclid = 0
        self._t_traject = 0
        self._t_cosine = 0
        self._t_hungarian = 0
    
    @property
    def n_det(self):
        return self._n_det

    @property
    def n_track(self):
        return self._n_track

    @property
    def t_det(self):
        return self._t_det

    @property
    def t_reid(self):
        return self._t_reid
    
    @property
    def t_euclid(self):
        return self._t_euclid
    
    @property
    def t_traject(self):
        return self._t_traject
    
    @property
    def t_cosine(self):
        return self._t_cosine
    
    @property
    def t_hungarian(self):
        return self._t_hungarian
    
    @n_det.setter
    def n_det(self, value):
        self._n_det = value

    @n_track.setter
    def n_track(self, value):
        self._n_track = value
    
    @t_det.setter
    def t_det(self, value):
        self._t_det = value

    @t_reid.setter
    def t_reid(self, value):
        self._t_reid = value
    
    @t_euclid.setter
    def t_euclid(self, value):
        self._t_euclid = value
    
    @t_traject.setter
    def t_traject(self, value):
        self._t_traject = value
    
    @t_cosine.setter
    def t_cosine(self, value):
        self._t_cosine = value
    
    @t_hungarian.setter
    def t_hungarian(self, value):
        self._t_hungarian = value

    def reset(self):
        self.t_det = 0
        self.n_track = 0
        self.t_det = 0
        self.t_reid = 0
        self.t_euclid = 0
        self.t_traject = 0
        self.t_cosine = 0
        self.t_hungarian = 0
    
    def write(self):
        self.f.write('{},{},{},{},{},{},{},{}\n'.format(self.n_det, self.n_track, self.t_det, self.t_reid, self.t_euclid, self.t_traject, self.t_cosine, self.t_hungarian))

# %% [markdown]
# # Cosine + trajectory utils

# %%
def pad_sequence_fixed_size(sequences, batch_first=False, padding_value=0.0, max_len=256):
  # based on torch.nn.utils.rnn.pad_sequence
    max_size = sequences[0].size()
    trailing_dims = max_size[1:]
    
    if batch_first:
        out_dims = (len(sequences), max_len) + trailing_dims
    else:
        out_dims = (max_len, len(sequences)) + trailing_dims

    out_tensor = sequences[0].new_full(out_dims, padding_value)
    for i, tensor in enumerate(sequences):
        length = tensor.size(0)
        # use index notation to prevent duplicate references to the tensor
        if batch_first:
            out_tensor[i, :length, ...] = tensor
        else:
            out_tensor[:length, i, ...] = tensor

    return out_tensor

def track2tensor(track, device, half):
    if half:
        item = torch.tensor(track, dtype=torch.float16, device=device).unsqueeze(0) 
    else:
        item = torch.tensor(track, dtype=torch.float, device=device).unsqueeze(0) 
    item = pad_sequence_fixed_size(item, batch_first=True, max_len=DataCFG.window_size)
    return item

def get_normalized_box(box_info, img_shape):
    h, w, c = img_shape
    x1 = float(box_info[0])/w
    x2 = float(box_info[1])/w
    y1 = float(box_info[2])/h
    y2 = float(box_info[3])/h
    return [x1, x2, y1, y2]

# %%
class Attention(nn.Module):
    def __init__(self, input_size, units=128, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.fc1 = nn.Linear(input_size, input_size, bias=False)
        self.fc2 = nn.Linear(input_size*2, self.units, bias = False)
    
    def forward(self, x):
        score_first_part = self.fc1(x)
        h_t = x[:, -1, :] # Last hidden state
        score = torch.einsum('ik,ijk->ij', h_t, score_first_part)
        attention_weights = F.softmax(score, dim=1)
        context_vector = torch.einsum('ijk,ij->ik', x, attention_weights)
        pre_activation = torch.cat([context_vector, h_t], dim=1)
        attention_vector = torch.tanh(self.fc2(pre_activation))
        return attention_vector

class Trajectory(nn.Module):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.lstm = nn.LSTM(input_size=4, hidden_size=100, dropout=0.2, num_layers=3, batch_first=True)
        self.attention = Attention(input_size=100, units=128)
        self.drop = nn.Dropout(0.2)
        self.fc = nn.Linear(128, DataCFG.n_id)
    
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.drop(out)
        att = self.attention(out)
        out = self.fc(att)
        return out, att

# %%
@dask.delayed
def load_transform(half, device, track_boxes, det_box = None):
    track = track_boxes[:]
    if det_box:
        track.append(det_box)
    tensor = track2tensor(track, device, half)
    return tensor

@dask.delayed
def predict(batch, model):
    with torch.no_grad():
        out, att = model(batch)
    return att

def get_trajectory_embeddings(tensors, dmodel):
    batches = [dask.delayed(torch.cat)(batch, dim=0)
            for batch in toolz.partition_all(opt.batch_size, tensors)]
    predictions = [predict(batch, dmodel) for batch in batches]
    predictions = dask.compute(*predictions)    
    if len(predictions)>0:
        predictions = torch.cat(predictions, dim=0)
    return predictions

def get_trajectory_matrix(tracks_box_list, det_boxes_list, trajectory_model, euclidean_matrix, trajectory_thresh, device, half):
    trajectory_matrix = {}
    # Get track trajectory embedding
    track_ids = sorted(tracks_box_list.keys())
    tensors = [load_transform(half, device, tracks_box_list[k]) for k in track_ids]
    track_predictions = get_trajectory_embeddings(tensors, trajectory_model)
    
    # Get candidate trajectory embedding
    tensors = []
    for k in track_ids:
        for j in range(len(det_boxes_list)):
            if euclidean_matrix[k][j] and len(tracks_box_list[k])>=opt.num_trajectory:
                tensors.append(load_transform(half, device, tracks_box_list[k], det_boxes_list[j]))
    predictions = get_trajectory_embeddings(tensors, trajectory_model)

    count = 0
    for i, k in enumerate(track_ids):
        score = []    
        for j in range(len(det_boxes_list)):
            if euclidean_matrix[k][j]:
                if len(tracks_box_list[k])<opt.num_trajectory:
                    score.append(True)
                else:
                    track_emb = track_predictions[i]
                    candidate_emb = predictions[count]
                    count += 1
                    score.append(float(F.cosine_similarity(track_emb, candidate_emb, dim=0)) >= trajectory_thresh)
            else:
                score.append(False)
        trajectory_matrix[k] = score
    return trajectory_matrix

# %%
def xyxy2cxcy(box):
    cx = statistics.mean([box[1], box[0]])
    cy = statistics.mean([box[3], box[2]])
    return (cx, cy)

def gt_cxcy(box):
    # [frame_id, x1, y1, w, h, cfs, cls]
    cx = box[1] + box[3]//2
    cy = box[2] + box[4]//2
    return (cx, cy)

def is_min_topk(a, k=1):
    '''
        Mask min top k values in array as 1, others as 0
    '''
    _, rix = np.unique(a, return_inverse=True)
    return np.where(rix < k, True, False).reshape(a.shape)

def get_euclidean_matrix(tracks_box_list, det_boxes_list, euclidean_num):
    matrix = {}
    track_ids = sorted(tracks_box_list.keys())
    det_boxes_cxcy = [xyxy2cxcy(det_box) for det_box in det_boxes_list]
    track_boxes_cxcy = []
    for k in track_ids:
        track_boxes_cxcy.append(xyxy2cxcy(tracks_box_list[k][-1]))
    
    scores = distance_matrix(track_boxes_cxcy, det_boxes_cxcy)
    for i, k in enumerate(track_ids):
        matrix[k] = is_min_topk(scores[i], euclidean_num)

    return matrix

def cosine_distance(X, Y, track_class_list, class_id, row2id, trajectory_matrix, INFY_COST=1e5):
    """Get cost matrix using cosine distance"""
    norm_1 = torch.norm(X, dim=1, keepdim=True)
    norm_2 = torch.norm(Y, dim=1, keepdim=True)
    
    cos_dis = 1 - (X@Y.T)/(norm_1@norm_2.T)
    cos_dis = cos_dis.cpu().numpy()
    for j in range(len(Y)):
        for i in range(len(X)):
            if track_class_list[i] != class_id[j] or not trajectory_matrix[row2id[i]][j]:
                cos_dis[i][j] = INFY_COST
    return cos_dis

# %% [markdown]
# # Online Inference

# %%
class Tracker:
    def __init__(self, opt, logger=None):
        self.opt = opt
        self.logger = logger
        set_logging()
        self.device = select_device(self.opt.device)
        self.half = self.device.type != 'cpu'  # half precision only supported on CUDA

        self.detector = self.load_detector(self.opt.detector_path)
        self.reid = VehicleEmbedder(self.opt.reid_path)
        self.trajectory_model = self.load_trajectory_model(self.opt.trajectory_path)

        self.frame_id = 1
        self.active_tracks = defaultdict(list)
        self.age = OrderedDict()
        self.num_tracks = 1

        # if not os.path.exists(self.opt.output):
        #     os.mkdir(self.opt.output)
        self.vid_writer = cv2.VideoWriter('/content/video.mp4', cv2.VideoWriter_fourcc(*'mp4v'), self.opt.video_fps, self.opt.video_resolution)
        self.check = defaultdict(list)
        self.vehicle_count = [0,0,0,0]

        self.f = open(opt.out_txt, 'w')
    
    def copy_video_to_destination(self):
        shutil.copy('/content/video.mp4', os.path.join(self.opt.output, 'video.mp4'))

    def load_detector(self, checkpoint_path):
        model = attempt_load(checkpoint_path, map_location=self.device)  # load FP32 model
        self.stride = int(model.stride.max())  # model stride
        self.imgsz = check_img_size(self.opt.img_size, s=self.stride)  # check img_size
        if self.half:
            model.half()  # to FP16 
        return model

    def load_trajectory_model(self, trajectory_path):
        model = Trajectory().to(self.device)
        checkpoint = torch.load(trajectory_path)
        model.load_state_dict(checkpoint["model_state_dict"])
        model.eval()
        if self.half:
            model.half()  # to FP16 
        model = dask.delayed(model)
        return model

    def add_track_info(self, embed, cls, det_boxes, track=None):
        if track is None:
            track = defaultdict(list)
        track['embed'].append(embed)
        track['class'].append(cls)
        track['norm_boxes'].append(det_boxes)

        track['embed'] = track['embed'][-self.opt.num_embed:]
        track['norm_boxes'] = track['norm_boxes'][-self.opt.num_trajectory:]
        return track

    def detect(self, img):
        start = time.time()

        with torch.no_grad():
            boxes = detectFromImage(self.detector, self.half, self.opt, self.device, self.imgsz, self.stride, img)
            box_info = []
            for b in boxes:
                x1, y1, x2, y2 = map(int, [b.x_min, b.y_min, b.x_max, b.y_max])
                w = x2 - x1
                h = y2 - y1
                cfs = 1
                cls = b.semantic_id
                box_info.append([self.frame_id, x1, y1, w, h, cfs, cls])

        if self.logger:
            self.logger.t_det = round((time.time() - start)*1000)
        return box_info
    
    def get_embedding(self, img, box_info):
        start = time.time()
        with torch.no_grad():            
            crop_imgs = []
            boxes = []
            for info in box_info:
                x1 = info[1]
                y1 = info[2]
                x2 = x1 + info[3]
                y2 = y1 + info[4]
                cfs = info[5]
                cls = info[6]
                if x1 < 0:
                    x1 = 0
                if x2 > img.shape[1]:
                    x2 = img.shape[1]
                if y1 < 0:
                    y1 = 0
                if y2 > img.shape[0]:
                    y2 = img.shape[0]
                
                if x1 >= x2 or y1 >= y2:
                    continue
                else:
                    cfs = info[5]
                    cls = info[6]
                    crop_imgs.append(img[y1:y2, x1:x2])
                    boxes.append([x1, x2, y1, y2, cfs, cls])

            if len(boxes)==0:
                return OrderedDict()
            
            embed_list = self.reid.infer(crop_imgs)
            embed_list = embed_list.cpu()
            # Normalize embed
            embed_dict = OrderedDict()
            embed_dict['embed'] = F.normalize(embed_list)
            embed_dict['boxes'] = boxes    
            embed_dict['norm_boxes'] = [get_normalized_box(item, img.shape) for item in boxes]

        if self.logger:
            self.logger.t_reid = round((time.time() - start)*1000)
        return embed_dict
    
    def matching_cascade(self, id_list, embed_list, class_list, check, det_boxes_list):
        row2id = {}
        track_embed_list = []
        track_class_list = []
        tracks_box_list = {}
        row_idx = 0

        for id, info in self.active_tracks.items():
            embeds = info['embed']
            classes = info['class']
            norm_boxes = info['norm_boxes']
            tracks_box_list[id] = norm_boxes[-self.opt.num_trajectory:]
            for i in range(len(embeds)):
                track_embed_list.append(embeds[i])
                track_class_list.append(classes[i])
                row2id[row_idx] = id
                row_idx += 1
        start = time.time()
        euclidean_matrix = get_euclidean_matrix(tracks_box_list, det_boxes_list, self.opt.euclidean_num)
        if self.logger:
            self.logger.t_euclid = round((time.time() - start)*1000)

        start = time.time()
        if self.opt.use_trajectory:
            trajectory_matrix = get_trajectory_matrix(tracks_box_list, det_boxes_list, self.trajectory_model, euclidean_matrix, self.opt.trajectory_thresh, self.device, self.half)
        else:
            trajectory_matrix = euclidean_matrix
        if self.logger:
            self.logger.t_traject = round((time.time() - start)*1000)

        start = time.time()
        reid_dists = cosine_distance(torch.stack(track_embed_list), embed_list, track_class_list, class_list, row2id, trajectory_matrix)
        if self.logger:
            self.logger.t_cosine = round((time.time() - start)*1000)
        start = time.time()
        row, col = linear_sum_assignment(reid_dists)
        if self.logger:
            self.logger.t_hungarian = round((time.time() - start)*1000)
        un_matched = [] # Những embedding mới chưa được match với id nào
        results = []
        for r, c in zip(row, col):
            dist = reid_dists[r, c]
            results.append([r, c, dist, row2id[r]])
        
        results.sort(key=lambda x: x[2])
        for r, c, dist, id in results:
            if dist < self.opt.match_score_thr:
                if not check[id]:
                    # Nếu id chưa được match 
                    id_list[c] = id
                    check[id] = True
                    self.active_tracks[id] = self.add_track_info(embed_list[c], class_list[c], det_boxes_list[c], self.active_tracks[id])
                    if len(self.active_tracks[id]['embed']) > self.opt.num_embed:
                        self.active_tracks[id]['embed'] = self.active_tracks[id]['embed'][-self.opt.num_embed:]
                        self.active_tracks[id]['norm_boxes'] = self.active_tracks[id]['norm_boxes'][-self.opt.num_trajectory:]
                else:
                    # Nếu id đã được matched rồi thì cho embedding đó vào tập chưa được match
                    un_matched.append(c)
            else:
                id_list[c] = self.num_tracks
                check[self.num_tracks] = True
                self.active_tracks[self.num_tracks] = self.add_track_info(embed_list[c], class_list[c], det_boxes_list[c])
                self.age[self.num_tracks] = 0
                self.num_tracks += 1
        
        return un_matched, id_list, check

    def matching(self, info):
        id_dict = OrderedDict()

        if len(info.keys())==0:
            for id, v in self.age.items():
                self.age[id] = self.age[id] + 1
            del_id = []
            for id, a in self.age.items():
                if a > self.opt.max_age:
                    del_id.append(id)
            for id in del_id:
                self.active_tracks.pop(id)
                self.age.pop(id)
            return id_dict
        
        embed_list = info['embed']
        boxes = info['boxes']
        norm_boxes = info['norm_boxes']
        class_list = []
        for i in range(len(boxes)):
            class_list.append(boxes[i][5])
        
        if len(self.active_tracks.keys()) == 0: # No active tracks
            id_list = []
            for i in range(embed_list.size(0)):
                self.active_tracks[self.num_tracks] = self.add_track_info(embed_list[i-1], boxes[i-1][5], norm_boxes[i-1])
                self.age[self.num_tracks] = 0
                id_list.append(self.num_tracks)
                self.num_tracks += 1
        else:
            id_list = [-1 for _ in range(embed_list.size(0))]
            check = defaultdict(list) # Kiểm tra xem các id đã được match chưa, ban đầu giá trị bằng False
            for id, _ in self.active_tracks.items():
                check[id] = False
            
            un_matched, id_list, check = self.matching_cascade(id_list, embed_list, class_list, check, norm_boxes)
            # Nếu vẫn còn embedding mới chưa được match với id nào
            if len(un_matched) != 0:
                for c in un_matched:
                    id_list[c] = self.num_tracks
                    check[self.num_tracks] = True
                    self.active_tracks[self.num_tracks] = self.add_track_info(embed_list[c], class_list[c], norm_boxes[c])
                    self.age[self.num_tracks] = 0
                    self.num_tracks += 1

            for k, id in enumerate(id_list):
                if id == -1:
                    id_list[k] = self.num_tracks
                    check[self.num_tracks] = True
                    self.active_tracks[self.num_tracks] = self.add_track_info(embed_list[k], class_list[k], norm_boxes[k])
                    self.age[self.num_tracks] = 0
                    self.num_tracks += 1

            for id, v in check.items():
                if not v:
                    self.age[id] = self.age[id] + 1
            del_id = []
            for id, a in self.age.items():
                if a > self.opt.max_age:
                    del_id.append(id)
            for id in del_id:
                self.active_tracks.pop(id)
                self.age.pop(id)
            
        id_dict = {}
        id_dict['id'] = id_list
        id_dict['boxes'] = boxes
        for i, box in enumerate(boxes):
            if box[5]<4 and id_list[i] not in self.check:
                self.check[id_list[i]] = True
                self.vehicle_count[box[5]] += 1
        return id_dict
    
    def process_one_frame(self, img, box_info=None):
        '''
            Process one frame
            img: input image frame
            box_info: public detection box if provided
        '''
        if self.logger:
            self.logger.reset()
        if box_info is None:
            box_info = self.detect(img)

        if self.logger:
            self.logger.n_det = len(box_info)
            self.logger.n_track = len(self.active_tracks.items())
        embed_dict = self.get_embedding(img, box_info)
        id_dict = self.matching(embed_dict)
        if self.logger:
            self.logger.write()

        self.frame_id += 1
        return id_dict
    
    def save_result(self, image, info):
        img = copy.deepcopy(image)
        colors = [(0, 255, 255), (0, 0, 255)]
        if len(info.keys())!=0:
            boxes = info['boxes']
            ids = info['id']
            for i, box in enumerate(boxes):
                cv2.rectangle(img, (box[0], box[2]), (box[1], box[3]), colors[1], 2)
                cv2.putText(img, str(ids[i]), (box[0], box[2]), cv2.FONT_HERSHEY_SIMPLEX, 1, colors[0], 2)
        cv2.rectangle(img, (0, 0), (int(img.shape[1]*0.3), int(img.shape[0]*0.07)), (0,0,0), -1)
        cv2.putText(img, "Frame: {} Motorcycle: {} Car: {} Pedestrian: {} Truck: {} Total: {}".format(self.frame_id-1, *self.vehicle_count, sum(self.vehicle_count)), (20, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, colors[0], 1)
        if self.opt.save_image:
            name_save = os.path.join(self.opt.output, str(self.frame_id-1).zfill(6) + '.jpg')
            cv2.imwrite(name_save, img)
        self.vid_writer.write(img)
    
    def save_txt(self, info):    
        if len(info.keys()) != 0:
            ids = info['id']
            boxes = info['boxes']
            results = []
            for i, id in enumerate(ids):
                x = boxes[i][0]
                y = boxes[i][2]
                w = boxes[i][1] - boxes[i][0]
                h = boxes[i][3] - boxes[i][2]
                cfs = boxes[i][4]
                cls = boxes[i][5]
                vs = 1
                results.append([self.frame_id, id, x, y, w, h, cfs, cls, vs])

            for i in range(len(results)):
                self.f.write(str(results[i][0]) + ',' +  str(results[i][1]) + ',' + str(results[i][2]) + ',' + \
                        str(results[i][3]) + ',' + str(results[i][4]) + ',' + str(results[i][5]) + ',' + \
                        str(results[i][6]) + ',' + str(results[i][7]) + ',' + str(results[i][8]) + '\n')

    def save_txt_mot(self, info):
        if len(info.keys()) != 0:
            ids = info['id']
            boxes = info['boxes']
            results = []
            for i, id in enumerate(ids):
                x = boxes[i][0]
                y = boxes[i][2]
                w = boxes[i][1] - boxes[i][0]
                h = boxes[i][3] - boxes[i][2]
                cfs = boxes[i][4]
                results.append([self.frame_id-1, id, x, y, w, h, cfs, -1, -1, -1])

            for res in results:
                self.f.write("{},{},{},{},{},{},{},{},{},{}\n".format(*res))
    
    def release_all(self):
        self.f.close()
        self.vid_writer.release()

# %%
def load_images_path(source):
    imgs = sorted(glob.glob(os.path.join(source, '*.jpg')))    
    return imgs

def get_box_from_file(source):
    boxes = []
    with open(source, 'r') as f:
        lines = f.readlines()

    for line in lines:
        line = line.strip('\n').split(",")
        boxes.append([int(line[0]), int(line[2]), int(line[3]), int(line[4]), int(line[5]), int(line[6]), int(line[7]), float(line[8])])
    return boxes

def get_box_from_file_det(source):
    boxes = []
    with open(source, 'r') as f:
        lines = f.readlines()
    for line in lines:
        line = line.strip('\n').split(",") # frame, id, x1, y1, w, h, cfs, x, y, z
        frame = int(line[0])
        x1 = round(float(line[2]))
        y1 = round(float(line[3]))
        w = round(float(line[4]))
        h = round(float(line[5]))
        cfs = 1 #float(line[6])
        cls = 1
        boxes.append([frame, x1, y1, w, h, cfs, cls])
    return boxes

def get_frame_boxes(boxes, frame_id):
    box_info = []
    for box in boxes:
        if box[0]==frame_id and box[5]>=0.25:
            box_info.append(box)
    return box_info

# %%
# vids = [
#         "MOT17-14-SDP", 
#         "MOT17-12-SDP",
#         "MOT17-08-SDP",
#         "MOT17-07-SDP",
#         "MOT17-06-SDP",
#         "MOT17-03-SDP",
#         "MOT17-01-SDP",
#         "MOT17-14-FRCNN", 
#         "MOT17-12-FRCNN",
#         "MOT17-08-FRCNN",
#         "MOT17-07-FRCNN",
#         "MOT17-06-FRCNN",
#         "MOT17-03-FRCNN",
#         "MOT17-01-FRCNN",
#         "MOT17-14-DPM", 
#         "MOT17-12-DPM",
#         "MOT17-08-DPM",
#         "MOT17-07-DPM",
#         "MOT17-06-DPM",
#         "MOT17-03-DPM",
#         "MOT17-01-DPM",
#         ]
# vids = [
#         "MOT17-13-SDP", 
#         "MOT17-11-SDP",
#         "MOT17-10-SDP",
#         "MOT17-09-SDP",
#         "MOT17-05-SDP",
#         "MOT17-04-SDP",
#         "MOT17-02-SDP",
#         "MOT17-13-FRCNN", 
#         "MOT17-11-FRCNN",
#         "MOT17-10-FRCNN",
#         "MOT17-09-FRCNN",
#         "MOT17-05-FRCNN",
#         "MOT17-04-FRCNN",
#         "MOT17-02-FRCNN",
#         "MOT17-13-DPM", 
#         "MOT17-11-DPM",
#         "MOT17-10-DPM",
#         "MOT17-09-DPM",
#         "MOT17-05-DPM",
#         "MOT17-04-DPM",
#         "MOT17-02-DPM",
#         ]

vids = [
        "MOT20-04",
        "MOT20-06",
        "MOT20-07",
        "MOT20-08",
        ]

# vids = [
#         "MOT20-01",
#         "MOT20-02",
#         "MOT20-03",
#         "MOT20-05",
#         ]

logger = Logger("/content/log.txt")
# logger = None

for vid_name in vids:
    print("*"*30)
    print(vid_name)
    opt = {
        'agnostic_nms': False, 
        'augment': False, 
        'batch_size': 128,
        'checkpoint_path':'weights/reid/epoch_13.pth',
        'classes': None, 
        'conf_thres': 0.25, 
        'config_path':'reid/configs/reid/resnet50_b32x8_MOT17_3000id.py',
        'detector_path': 'weights/yolov5/pedestrian_21.pt', 
        'device': 'cuda', 
        'euclidean_num': 5,
        'exist_ok': False,
        'file_det': f'/content/MOT20/test/{vid_name}/det/det.txt',
        'img_size': 640, 
        'iou_thres': 0.45, 
        'n_image': 100, 
        'name': 'exp', 
        'num_embed': 5,
        'num_trajectory': 3, 
        'match_score_thr': 0.5,
        'max_age': 32,
        'output':f'output/MOT20/{vid_name}',
        'out_txt':f'output/MOT20/test_test_txt/{vid_name}.txt',
        'save_conf': False, 
        'save_embed':True,
        'save_txt': False, 
        'source': f'/content/MOT20/test/{vid_name}/img1',
        'trajectory_thresh': 0.9, 
        'trajectory_path':'weights/trajectory/best_400class_10_3.pth', 
        'reid_path':'weights/reid/reid_new_48.pt',
        'update': False, 
        'use_trajectory': False,
        'video_fps': 10, 
        'video_resolution': (1280, 720), 
        }

    opt = dotdict(opt)
    imgs = load_images_path(opt.source)
    boxes = get_box_from_file_det(opt.file_det)
    tracker = Tracker(opt, logger)

    for img_path in tqdm(imgs):
        img = cv2.imread(img_path)                
        box_info = get_frame_boxes(boxes, int(img_path.split('/')[-1].split('.')[0])) # Public detection boxes
        id_dict = tracker.process_one_frame(img)
        tracker.save_txt_mot(id_dict)
    tracker.release_all()

if logger:
    logger.f.close()
# Out:
# ******************************
# MOT20-04
# YOLOv5 🚀 2021-10-13 torch 1.9.0+cu111 CUDA:cuda (Tesla P100-PCIE-16GB, 16280.875MB)
# run
# Fusing layers...
# Model Summary: 476 layers, 87198694 parameters, 0 gradients
# SelecSLS42_B
#   1%|▏         | 27/2080 [00:16<21:14,  1.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-aaca7c160de1> in <module>()
#     109     for img_path in tqdm(imgs):
#     110         img = cv2.imread(img_path)
# --> 111         box_info = get_frame_boxes(boxes, int(img_path.split('/')[-1].split('.')[0])) # Public detection boxes
#     112         id_dict = tracker.process_one_frame(img)
#     113         tracker.save_txt_mot(id_dict)
#
# <ipython-input-17-7e4f823af5ab> in get_frame_boxes(boxes, frame_id)
#      32     box_info = []
#      33     for box in boxes:
# ---> 34         if box[0]==frame_id and box[5]>=0.25:
#      35             box_info.append(box)
#      36     return box_info
#
# KeyboardInterrupt:

# %%
shutil.copy("/content/log.txt", "/content/drive/MyDrive/Viettel DTalent/ViettelTalentsPhase2/Phan Nhật Minh/track_v2/output/MOT20/mot20_test_test_log.txt")
